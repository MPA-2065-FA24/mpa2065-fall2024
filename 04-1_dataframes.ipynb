# %% [markdown]
# <center><h1>Dataframes, Tidy data, Tidyverse</h1></center>
# <center><h3>Ellen Duong</h3></center>
# <center><h3>August Guang</h3></center>
# <center><h3>Paul Stey</h3></center>
# <center><h3>2024-09-18</h3></center>

# %% [markdown]
# # 1. Review: What is a `data.frame`?
#
#   - Tabular data structure (i.e., like Excel spreadsheet)
#   - Canonical data structure for data analysis
#   - Capable of storing heterogeneous data

# %% [markdown]
# ## 1.1 What does it look like?

# %%
idx <- 1:4
score <- rnorm(4)
vocals <- c(TRUE, TRUE, TRUE, FALSE)
firstname <- c("john", "george", "paul", "ringo")

dat <- data.frame(idx, firstname, score, vocals)

dat
# Out:
#   idx firstname score       vocals
# 1 1   john       0.26741110  TRUE
# 2 2   george     0.43793860  TRUE
# 3 3   paul       0.78634455  TRUE
# 4 4   ringo     -0.09074287 FALSE

# %% [markdown]
# ## 1.2 Indexing and Slicing a `data.frame`
#
#   - Similar to `vector`, `matrix`, and `array` objects

# %%
dat[1, 2]           # get element in first row, second column
# Out:
# [1] "john"

# %%
dat[, 2]            # get all of second column
# Out:
# [1] "john"   "george" "paul"   "ringo"

# %%
dat[3, ]            # get third row
# Out:
#   idx firstname score     vocals
# 3 3   paul      0.7863446 TRUE

# %% [markdown]
# ### 1.2.1 Indexing using Column Names

# %%
dat[3, "score"]          # element from row 3 and "score" column
# Out:
# [1] 0.7863446

# %%
dat[2:4, "firstname"]    # get elements 2, 3, and 4 from "firstname" column
# Out:
# [1] "george" "paul"   "ringo"

# %% [markdown]
# ## 1.3 The `$` Operator and `data.frame` Objects

# %%
dat$firstname            # get the "firstname" column
# Out:
# [1] "john"   "george" "paul"   "ringo"

# %% [markdown]
# # 2. Filter `data.frame` using Logical Indexing

# %%
dat
# Out:
#   idx firstname score       vocals
# 1 1   john       0.26741110  TRUE
# 2 2   george     0.43793860  TRUE
# 3 3   paul       0.78634455  TRUE
# 4 4   ringo     -0.09074287 FALSE

# %%
idx_keep <- c(TRUE, TRUE, TRUE, FALSE)

dat[idx_keep, ]
# Out:
#   idx firstname score     vocals
# 1 1   john      0.2674111 TRUE
# 2 2   george    0.4379386 TRUE
# 3 3   paul      0.7863446 TRUE

# %% [markdown]
# ## 2.1 Create New `data.frame` from Another

# %%
dat2 <- dat[idx_keep, ]       # create new dataframe, from subset of original

tail(dat2, n=2)
# Out:
#   idx firstname score     vocals
# 2 2   george    0.4379386 TRUE
# 3 3   paul      0.7863446 TRUE

# %% [markdown]
# ### 2.1.1 Take Subset of `data.frame` Columns

# %%
cols <- c("firstname", "score")    # columns we care about

dat_namescore <- dat2[, cols]      # create new dataframe

dat_namescore
# Out:
#   firstname score
# 1 john      0.2674111
# 2 george    0.4379386
# 3 paul      0.7863446

# %% [markdown]
# # 3. Adding Columns to a `data.frame`

# %%
dat
# Out:
#   idx firstname score       vocals
# 1 1   john       0.26741110  TRUE
# 2 2   george     0.43793860  TRUE
# 3 3   paul       0.78634455  TRUE
# 4 4   ringo     -0.09074287 FALSE

# %%
dat$food <- c("steak", "chicken", "potato", "rice")

dat
# Out:
#   idx firstname score       vocals food
# 1 1   john       0.26741110  TRUE  steak
# 2 2   george     0.43793860  TRUE  chicken
# 3 3   paul       0.78634455  TRUE  potato
# 4 4   ringo     -0.09074287 FALSE  rice

# %% [markdown]
# ## 3.1. Adding Columns (cont.)

# %%
dat[, "drink"] <- c("water", "milk", "beer", "scotch")

dat
# Out:
#   idx firstname score       vocals food    drink
# 1 1   john       0.26741110  TRUE  steak   water
# 2 2   george     0.43793860  TRUE  chicken milk
# 3 3   paul       0.78634455  TRUE  potato  beer
# 4 4   ringo     -0.09074287 FALSE  rice    scotch

# %% [markdown]
# <center><h1>Challenge Questions</h1></center>
#
# ### Question 1.
# Create a `data.frame` object called `state_df` with two columns, one called `state` and one called `population`. Each column should have five elements. For the `state` column, select the abbreviations for five US states (e.g., "OH", "RI", "NY", "MA", "CT"). For the `population` column, use the `sample()` function to create "populations" at random from the range `1` to `1000000`.

# %%
# Your code here

# %% [markdown]
# ### Question 2.
# Add a third column to the `state_df` dataframe called `size`. In particular, use boolean indexing to assign elements of the third column to be `"large"` if that row's `population` value is larger than or equal to `500000`, and be `"small"`  if the row's `population` is less than `500000`.

# %%
# Your code here

# %% [markdown]
# # 4. Reading Data from CSV File
#
#   - CSV File is "comma-separated values"
#   - The `,` separator is conventional, but not mandatory
#   - The `|` character is also common
#   - `read.csv()` is a form of `read.table()` with specific arguments for comma-delimited files
#   - The `read.csv()` function has many optional arguments
#   - Critically, we can tell R the strings that ought to be considered missing

# %% [markdown]
# ## 4.1 Providence Police Dept. Data
#
#   - We will be looking at public data regarding arrests and case

# %%
# The line below reads the CSV file and creates a dataframe 

arrests_df <- read.csv("data/pvd_arrests_2021-10-03.csv")

# %% [markdown]
# ## 4.2 Exploring the Data

# %%
head(arrests_df)         # show first few lines of the dataframe
# Out:
#   arrest_date           year month gender race  ethnicity   year_of_birth age
# 1 2019-08-24T02:23:00.0 2019 8     Male   White NonHispanic 1981          37
# 2 2019-08-24T02:02:00.0 2019 8                              1994          25
# 3 2019-08-24T02:02:00.0 2019 8     Female Black NonHispanic 1984          34
# 4 2019-08-24T02:02:00.0 2019 8     Female Black NonHispanic 1984          34
# 5 2019-08-24T02:02:00.0 2019 8     Female Black Unknown     2001          18
# 6 2019-08-24T02:02:00.0 2019 8     Female Black Unknown     2001          18
#   from_address         from_city  from_state   statute_type
# 1 No Permanent Address providence Rhode Island
# 2 SUMMER AVE           Cranston   Rhode Island RI Statute Violation
# 3 DOUGLAS AVE          Providence Rhode Island RI Statute Violation
# 4 DOUGLAS AVE          Providence Rhode Island RI Statute Violation
# 5 TRASH ST                                     RI Statute Violation
# 6 TRASH ST                                     RI Statute Violation
#   statute_code statute_desc                                              counts
# 1                                                                        NA
# 2 31-11-18     Driving after Denial, Suspension or Revocation of License  1
# 3 12-7-10      RESISTING LEGAL OR ILLEGAL ARREST                          1
# 4 11-45-1      DISORDERLY CONDUCT                                         1
# 5 12-7-10      RESISTING LEGAL OR ILLEGAL ARREST                          1
# 6 11-45-1      DISORDERLY CONDUCT                                         1
#   case_number   arresting_officers       id
# 1 2019-00084142  YGonzalez, LTaveras     pvd2218242150382148273
# 2 2019-00084127  NManfredi               pvd15166785558364246202
# 3 2019-00084126  MPlace, JPerez, ASantos pvd3142917706201385905
# 4 2019-00084126  MPlace, JPerez, ASantos pvd3142917706201385905
# 5 2019-00084126  MPlace, JPerez, ASantos pvd460449304532374599
# 6 2019-00084126  MPlace, JPerez, ASantos pvd460449304532374599

# %% [markdown]
# ### 4.2.1 More Data Exploring

# %%
dim(arrests_df)             # get dimensions of the dataframe
# Out:
# [1] 13012    18

# %%
nrow(arrests_df)            # get number of rows
# Out:
# [1] 13012

# %%
ncol(arrests_df)            # get the number of columns
# Out:
# [1] 18

# %%
colnames(arrests_df)        # get the column names
# Out:
#  [1] "arrest_date"        "year"               "month"
#  [4] "gender"             "race"               "ethnicity"
#  [7] "year_of_birth"      "age"                "from_address"
# [10] "from_city"          "from_state"         "statute_type"
# [13] "statute_code"       "statute_desc"       "counts"
# [16] "case_number"        "arresting_officers" "id"

# %% [markdown]
# ### 4.2.2 Summaries from `data.frame`

# %%
str(arrests_df)              # the str() function shows the structure of dataframe
# Out:
# 'data.frame':	13012 obs. of  18 variables:
#  $ arrest_date       : chr  "2019-08-24T02:23:00.0" "2019-08-24T02:02:00.0" "2019-08-24T02:02:00.0" "2019-08-24T02:02:00.0" ...
#  $ year              : int  2019 2019 2019 2019 2019 2019 2019 2019 2019 2019 ...
#  $ month             : int  8 8 8 8 8 8 8 8 8 8 ...
#  $ gender            : chr  "Male" "" "Female" "Female" ...
#  $ race              : chr  "White" "" "Black" "Black" ...
#  $ ethnicity         : chr  "NonHispanic" "" "NonHispanic" "NonHispanic" ...
#  $ year_of_birth     : int  1981 1994 1984 1984 2001 2001 2001 1991 1991 1991 ...
#  $ age               : int  37 25 34 34 18 18 18 28 28 28 ...
#  $ from_address      : chr  "No Permanent Address" "SUMMER AVE" "DOUGLAS AVE" "DOUGLAS AVE" ...
#  $ from_city         : chr  "providence" "Cranston" "Providence" "Providence" ...
#  $ from_state        : chr  "Rhode Island" "Rhode Island" "Rhode Island" "Rhode Island" ...
#  $ statute_type      : chr  "" "RI Statute Violation" "RI Statute Violation" "RI Statute Violation" ...
#  $ statute_code      : chr  "" "31-11-18" "12-7-10" "11-45-1" ...
#  $ statute_desc      : chr  "" "Driving after Denial, Suspension or Revocation of License" "RESISTING LEGAL OR ILLEGAL ARREST" "DISORDERLY CONDUCT" ...
#  $ counts            : int  NA 1 1 1 1 1 1 1 1 1 ...
#  $ case_number       : chr  "2019-00084142" "2019-00084127" "2019-00084126" "2019-00084126" ...
#  $ arresting_officers: chr  " YGonzalez, LTaveras" " NManfredi" " MPlace, JPerez, ASantos" " MPlace, JPerez, ASantos" ...
#  $ id                : chr  "pvd2218242150382148273" "pvd15166785558364246202" "pvd3142917706201385905" "pvd3142917706201385905" ...

# %% [markdown]
# ### 4.2.3 Summarizing Numeric Data

# %%
summary(arrests_df)
# Out:
#  arrest_date             year          month           gender
#  Length:13012       Min.   :2019   Min.   : 1.000   Length:13012
#  Class :character   1st Qu.:2019   1st Qu.: 3.000   Class :character
#  Mode  :character   Median :2020   Median : 7.000   Mode  :character
#                     Mean   :2020   Mean   : 6.508
#                     3rd Qu.:2021   3rd Qu.: 9.000
#                     Max.   :2021   Max.   :12.000
#
#      race            ethnicity         year_of_birth       age
#  Length:13012       Length:13012       Min.   :1938   Min.   :18.00
#  Class :character   Class :character   1st Qu.:1980   1st Qu.:24.00
#  Mode  :character   Mode  :character   Median :1989   Median :31.00
#                                        Mean   :1986   Mean   :33.07
#                                        3rd Qu.:1995   3rd Qu.:39.00
#                                        Max.   :2003   Max.   :83.00
#
#  from_address        from_city          from_state        statute_type
#  Length:13012       Length:13012       Length:13012       Length:13012
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#
#  statute_code       statute_desc           counts       case_number
#  Length:13012       Length:13012       Min.   : 1.000   Length:13012
#  Class :character   Class :character   1st Qu.: 1.000   Class :character
#  Mode  :character   Mode  :character   Median : 1.000   Mode  :character
#                                        Mean   : 1.087
#                                        3rd Qu.: 1.000
#                                        Max.   :15.000
#                                        NA's   :2983
#  arresting_officers      id
#  Length:13012       Length:13012
#  Class :character   Class :character
#  Mode  :character   Mode  :character

# %% [markdown]
# ### 4.2.4 Summarizing Numeric Data (cont.)

# %%
numeric_vars <- c("month", "year", "age", "year_of_birth", "counts")

# %%
summary(arrests_df[, numeric_vars])
# Out:
#      month             year           age        year_of_birth
#  Min.   : 1.000   Min.   :2019   Min.   :18.00   Min.   :1938
#  1st Qu.: 3.000   1st Qu.:2019   1st Qu.:24.00   1st Qu.:1980
#  Median : 7.000   Median :2020   Median :31.00   Median :1989
#  Mean   : 6.508   Mean   :2020   Mean   :33.07   Mean   :1986
#  3rd Qu.: 9.000   3rd Qu.:2021   3rd Qu.:39.00   3rd Qu.:1995
#  Max.   :12.000   Max.   :2021   Max.   :83.00   Max.   :2003
#
#      counts
#  Min.   : 1.000
#  1st Qu.: 1.000
#  Median : 1.000
#  Mean   : 1.087
#  3rd Qu.: 1.000
#  Max.   :15.000
#  NA's   :2983

# %% [markdown]
# ### 4.2.5 Summarizing String Variables
#
# What's wrong with the data in the summary here?

# %%
table(arrests_df$race)           # show summary of "race" column in `arrests_df`
# Out:
#                                American Indian/Alaskan Native
#                             24                             25
#         Asian/Pacific Islander                          Black
#                            121                           5721
#                           NULL                        Unknown
#                             41                            588
#                          White            ZHispanic (FD only)
#                           6483                              9

# %% [markdown]
# ## 4.3 Utilizing `read.csv` options
#
# What option in `read.csv` would help with the issue above?

# %%
help(read.csv)
# Out:
# read.table                package:utils                R Documentation
#
# t
#
# n:
#
#      Reads a file in table format and creates a data frame from it,
#      with cases corresponding to lines and variables to fields in the
#      file.
#
# e:
#
#      read.table(file, header = FALSE, sep = "", quote = "\"'",
#                 dec = ".", numerals = c("allow.loss", "warn.loss", "no.loss"),
#                 row.names, col.names, as.is = !stringsAsFactors,
#                 na.strings = "NA", colClasses = NA, nrows = -1,
#                 skip = 0, check.names = TRUE, fill = !blank.lines.skip,
#                 strip.white = FALSE, blank.lines.skip = TRUE,
#                 comment.char = "#",
#                 allowEscapes = FALSE, flush = FALSE,
#                 stringsAsFactors = FALSE,
#                 fileEncoding = "", encoding = "unknown", text, skipNul = FALSE)
#
#      read.csv(file, header = TRUE, sep = ",", quote = "\"",
#               dec = ".", fill = TRUE, comment.char = "", ...)
#
#      read.csv2(file, header = TRUE, sep = ";", quote = "\"",
#                dec = ",", fill = TRUE, comment.char = "", ...)
#
#      read.delim(file, header = TRUE, sep = "\t", quote = "\"",
#                 dec = ".", fill = TRUE, comment.char = "", ...)
#
#      read.delim2(file, header = TRUE, sep = "\t", quote = "\"",
#                  dec = ",", fill = TRUE, comment.char = "", ...)
#
# s:
#
#     file: the name of the file which the data are to be read from.
#           Each row of the table appears as one line of the file.  If it
#           does not contain an _absolute_ path, the file name is
#           _relative_ to the current working directory, ‘getwd()’.
#           Tilde-expansion is performed where supported.  This can be a
#           compressed file (see ‘file’).
#
#           Alternatively, ‘file’ can be a readable text-mode connection
#           (which will be opened for reading if necessary, and if so
#           ‘close’d (and hence destroyed) at the end of the function
#           call).  (If ‘stdin()’ is used, the prompts for lines may be
#           somewhat confusing.  Terminate input with a blank line or an
#           EOF signal, ‘Ctrl-D’ on Unix and ‘Ctrl-Z’ on Windows.  Any
#           pushback on ‘stdin()’ will be cleared before return.)
#
#           ‘file’ can also be a complete URL.  (For the supported URL
#           schemes, see the ‘URLs’ section of the help for ‘url’.)
#
#   header: a logical value indicating whether the file contains the
#           names of the variables as its first line.  If missing, the
#           value is determined from the file format: ‘header’ is set to
#           ‘TRUE’ if and only if the first row contains one fewer field
#           than the number of columns.
#
#      sep: the field separator character.  Values on each line of the
#           file are separated by this character.  If ‘sep = ""’ (the
#           default for ‘read.table’) the separator is ‘white space’,
#           that is one or more spaces, tabs, newlines or carriage
#           returns.
#
#    quote: the set of quoting characters. To disable quoting altogether,
#           use ‘quote = ""’.  See ‘scan’ for the behaviour on quotes
#           embedded in quotes.  Quoting is only considered for columns
#           read as character, which is all of them unless ‘colClasses’
#           is specified.
#
#      dec: the character used in the file for decimal points.
#
# numerals: string indicating how to convert numbers whose conversion to
#           double precision would lose accuracy, see ‘type.convert’.
#           Can be abbreviated.  (Applies also to complex-number inputs.)
#
# row.names: a vector of row names.  This can be a vector giving the
#           actual row names, or a single number giving the column of the
#           table which contains the row names, or character string
#           giving the name of the table column containing the row names.
#
#           If there is a header and the first row contains one fewer
#           field than the number of columns, the first column in the
#           input is used for the row names.  Otherwise if ‘row.names’ is
#           missing, the rows are numbered.
#
#           Using ‘row.names = NULL’ forces row numbering. Missing or
#           ‘NULL’ ‘row.names’ generate row names that are considered to
#           be ‘automatic’ (and not preserved by ‘as.matrix’).
#
# col.names: a vector of optional names for the variables.  The default
#           is to use ‘"V"’ followed by the column number.
#
#    as.is: controls conversion of character variables (insofar as they
#           are not converted to logical, numeric or complex) to factors,
#           if not otherwise specified by ‘colClasses’.  Its value is
#           either a vector of logicals (values are recycled if
#           necessary), or a vector of numeric or character indices which
#           specify which columns should not be converted to factors.
#
#           Note: to suppress all conversions including those of numeric
#           columns, set ‘colClasses = "character"’.
#
#           Note that ‘as.is’ is specified per column (not per variable)
#           and so includes the column of row names (if any) and any
#           columns to be skipped.
#
# na.strings: a character vector of strings which are to be interpreted
#           as ‘NA’ values.  Blank fields are also considered to be
#           missing values in logical, integer, numeric and complex
#           fields.  Note that the test happens _after_ white space is
#           stripped from the input, so ‘na.strings’ values may need
#           their own white space stripped in advance.
#
# colClasses: character.  A vector of classes to be assumed for the
#           columns.  If unnamed, recycled as necessary.  If named, names
#           are matched with unspecified values being taken to be ‘NA’.
#
#           Possible values are ‘NA’ (the default, when ‘type.convert’ is
#           used), ‘"NULL"’ (when the column is skipped), one of the
#           atomic vector classes (logical, integer, numeric, complex,
#           character, raw), or ‘"factor"’, ‘"Date"’ or ‘"POSIXct"’.
#           Otherwise there needs to be an ‘as’ method (from package
#           ‘methods’) for conversion from ‘"character"’ to the specified
#           formal class.
#
#           Note that ‘colClasses’ is specified per column (not per
#           variable) and so includes the column of row names (if any).
#
#    nrows: integer: the maximum number of rows to read in.  Negative and
#           other invalid values are ignored.
#
#     skip: integer: the number of lines of the data file to skip before
#           beginning to read data.
#
# check.names: logical.  If ‘TRUE’ then the names of the variables in the
#           data frame are checked to ensure that they are syntactically
#           valid variable names.  If necessary they are adjusted (by
#           ‘make.names’) so that they are, and also to ensure that there
#           are no duplicates.
#
#     fill: logical. If ‘TRUE’ then in case the rows have unequal length,
#           blank fields are implicitly added.  See ‘Details’.
#
# strip.white: logical. Used only when ‘sep’ has been specified, and
#           allows the stripping of leading and trailing white space from
#           unquoted ‘character’ fields (‘numeric’ fields are always
#           stripped).  See ‘scan’ for further details (including the
#           exact meaning of ‘white space’), remembering that the columns
#           may include the row names.
#
# blank.lines.skip: logical: if ‘TRUE’ blank lines in the input are
#           ignored.
#
# comment.char: character: a character vector of length one containing a
#           single character or an empty string.  Use ‘""’ to turn off
#           the interpretation of comments altogether.
#
# allowEscapes: logical.  Should C-style escapes such as ‘\n’ be
#           processed or read verbatim (the default)?  Note that if not
#           within quotes these could be interpreted as a delimiter (but
#           not as a comment character).  For more details see ‘scan’.
#
#    flush: logical: if ‘TRUE’, ‘scan’ will flush to the end of the line
#           after reading the last of the fields requested.  This allows
#           putting comments after the last field.
#
# stringsAsFactors: logical: should character vectors be converted to
#           factors?  Note that this is overridden by ‘as.is’ and
#           ‘colClasses’, both of which allow finer control.
#
# fileEncoding: character string: if non-empty declares the encoding used
#           on a file (not a connection) so the character data can be
#           re-encoded.  See the ‘Encoding’ section of the help for
#           ‘file’, the ‘R Data Import/Export’ manual and ‘Note’.
#
# encoding: encoding to be assumed for input strings.  It is used to mark
#           character strings as known to be in Latin-1 or UTF-8 (see
#           ‘Encoding’): it is not used to re-encode the input, but
#           allows R to handle encoded strings in their native encoding
#           (if one of those two).  See ‘Value’ and ‘Note’.
#
#     text: character string: if ‘file’ is not supplied and this is, then
#           data are read from the value of ‘text’ via a text connection.
#           Notice that a literal string can be used to include (small)
#           data sets within R code.
#
#  skipNul: logical: should nuls be skipped?
#
#      ...: Further arguments to be passed to ‘read.table’.
#
# s:
#
#      This function is the principal means of reading tabular data into
#      R.
#
#      Unless ‘colClasses’ is specified, all columns are read as
#      character columns and then converted using ‘type.convert’ to
#      logical, integer, numeric, complex or (depending on ‘as.is’)
#      factor as appropriate.  Quotes are (by default) interpreted in all
#      fields, so a column of values like ‘"42"’ will result in an
#      integer column.
#
#      A field or line is ‘blank’ if it contains nothing (except
#      whitespace if no separator is specified) before a comment
#      character or the end of the field or line.
#
#      If ‘row.names’ is not specified and the header line has one less
#      entry than the number of columns, the first column is taken to be
#      the row names.  This allows data frames to be read in from the
#      format in which they are printed.  If ‘row.names’ is specified and
#      does not refer to the first column, that column is discarded from
#      such files.
#
#      The number of data columns is determined by looking at the first
#      five lines of input (or the whole input if it has less than five
#      lines), or from the length of ‘col.names’ if it is specified and
#      is longer.  This could conceivably be wrong if ‘fill’ or
#      ‘blank.lines.skip’ are true, so specify ‘col.names’ if necessary
#      (as in the ‘Examples’).
#
#      ‘read.csv’ and ‘read.csv2’ are identical to ‘read.table’ except
#      for the defaults.  They are intended for reading ‘comma separated
#      value’ files (‘.csv’) or (‘read.csv2’) the variant used in
#      countries that use a comma as decimal point and a semicolon as
#      field separator.  Similarly, ‘read.delim’ and ‘read.delim2’ are
#      for reading delimited files, defaulting to the TAB character for
#      the delimiter.  Notice that ‘header = TRUE’ and ‘fill = TRUE’ in
#      these variants, and that the comment character is disabled.
#
#      The rest of the line after a comment character is skipped; quotes
#      are not processed in comments.  Complete comment lines are allowed
#      provided ‘blank.lines.skip = TRUE’; however, comment lines prior
#      to the header must have the comment character in the first
#      non-blank column.
#
#      Quoted fields with embedded newlines are supported except after a
#      comment character.  Embedded nuls are unsupported: skipping them
#      (with ‘skipNul = TRUE’) may work.
#
# e:
#
#      A data frame (‘data.frame’) containing a representation of the
#      data in the file.
#
#      Empty input is an error unless ‘col.names’ is specified, when a
#      0-row data frame is returned: similarly giving just a header line
#      if ‘header = TRUE’ results in a 0-row data frame.  Note that in
#      either case the columns will be logical unless ‘colClasses’ was
#      supplied.
#
#      Character strings in the result (including factor levels) will
#      have a declared encoding if ‘encoding’ is ‘"latin1"’ or ‘"UTF-8"’.
#
# s:
#
#      See the help on ‘write.csv’ for the various conventions for ‘.csv’
#      files.  The commonest form of CSV file with row names needs to be
#      read with ‘read.csv(..., row.names = 1)’ to use the names in the
#      first column of the file as row names.
#
# e:
#
#      These functions can use a surprising amount of memory when reading
#      large files.  There is extensive discussion in the ‘R Data
#      Import/Export’ manual, supplementing the notes here.
#
#      Less memory will be used if ‘colClasses’ is specified as one of
#      the six atomic vector classes.  This can be particularly so when
#      reading a column that takes many distinct numeric values, as
#      storing each distinct value as a character string can take up to
#      14 times as much memory as storing it as an integer.
#
#      Using ‘nrows’, even as a mild over-estimate, will help memory
#      usage.
#
#      Using ‘comment.char = ""’ will be appreciably faster than the
#      ‘read.table’ default.
#
#      ‘read.table’ is not the right tool for reading large matrices,
#      especially those with many columns: it is designed to read _data
#      frames_ which may have columns of very different classes.  Use
#      ‘scan’ instead for matrices.
#
# e:
#
#      The columns referred to in ‘as.is’ and ‘colClasses’ include the
#      column of row names (if any).
#
#      There are two approaches for reading input that is not in the
#      local encoding.  If the input is known to be UTF-8 or Latin1, use
#      the ‘encoding’ argument to declare that.  If the input is in some
#      other encoding, then it may be translated on input.  The
#      ‘fileEncoding’ argument achieves this by setting up a connection
#      to do the re-encoding into the current locale.  Note that on
#      Windows or other systems not running in a UTF-8 locale, this may
#      not be possible.
#
# s:
#
#      Chambers, J. M. (1992) _Data for models._ Chapter 3 of
#      _Statistical Models in S_ eds J. M. Chambers and T. J. Hastie,
#      Wadsworth & Brooks/Cole.
#
# o:
#
#      The ‘R Data Import/Export’ manual.
#
#      ‘scan’, ‘type.convert’, ‘read.fwf’ for reading _f_ixed _w_idth
#      _f_ormatted input; ‘write.table’; ‘data.frame’.
#
#      ‘count.fields’ can be useful to determine problems with reading
#      files which result in reports of incorrect record lengths (see the
#      ‘Examples’ below).
#
#      <https://tools.ietf.org/html/rfc4180> for the IANA definition of
#      CSV files (which requires comma as separator and CRLF line
#      endings).
#
# s:
#
#      ## using count.fields to handle unknown maximum number of fields
#      ## when fill = TRUE
#      test1 <- c(1:5, "6,7", "8,9,10")
#      tf <- tempfile()
#      writeLines(test1, tf)
#
#      read.csv(tf, fill = TRUE) # 1 column
#      ncol <- max(count.fields(tf, sep = ","))
#      read.csv(tf, fill = TRUE, header = FALSE,
#               col.names = paste0("V", seq_len(ncol)))
#      unlink(tf)
#
#      ## "Inline" data set, using text=
#      ## Notice that leading and trailing empty lines are auto-trimmed
#
#      read.table(header = TRUE, text = "
#      a b
#      1 2
#      3 4
#      ")

# %%
arrests_df2 <- read.csv("data/pvd_arrests_2021-10-03.csv", 
                        na.strings = c("NA", "", " ", "NULL", "Unknown"))

# %% [markdown]
# ### 4.3.1 Effects of  `na.strings`

# %%
table(arrests_df$race)             # explore `race` in original dataframe
# Out:
#                                American Indian/Alaskan Native
#                             24                             25
#         Asian/Pacific Islander                          Black
#                            121                           5721
#                           NULL                        Unknown
#                             41                            588
#                          White            ZHispanic (FD only)
#                           6483                              9

# %%
table(arrests_df2$race)           # dataframe after setting `na.strings`
# Out:
# American Indian/Alaskan Native         Asian/Pacific Islander
#                             25                            121
#                          Black                          White
#                           5721                           6483
#            ZHispanic (FD only)
#                              9

# %%
arrests_df[1, ]
# Out:
#   arrest_date           year month gender race  ethnicity   year_of_birth age
# 1 2019-08-24T02:23:00.0 2019 8     Male   White NonHispanic 1981          37
#   from_address         from_city  from_state   statute_type statute_code
# 1 No Permanent Address providence Rhode Island
#   statute_desc counts case_number   arresting_officers   id
# 1              NA     2019-00084142  YGonzalez, LTaveras pvd2218242150382148273

# %% [markdown]
# # 5. Data frame merging
# - Data is often spread across more than one file, reading each file into R will result in more than one data frame.
# - If the data frames have some common identifying column, we can use that common ID to combine the data frames.
#
# For example, in addition to the arrests data, the Providence Police Department also makes data concerning criminal cases available. This is in the CSV file called `"pvd_cases_2021-10-03.csv"` in the `data/` directory of this repository.
#
#   1. Let's read the cases data in from a CSV and call it `cases_df`.
#   2. What columns do `cases_df` and `arrests_df2` share in common?

# %%
cases_df <- read.csv("data/pvd_cases_2021-10-03.csv")

# %%
colnames(cases_df)
# Out:
#  [1] "casenumber"        "location"          "reported_date"
#  [4] "month"             "year"              "offense_desc"
#  [7] "statute_code"      "statute_desc"      "counts"
# [10] "reporting_officer"

# %%
colnames(arrests_df2)
# Out:
#  [1] "arrest_date"        "year"               "month"
#  [4] "gender"             "race"               "ethnicity"
#  [7] "year_of_birth"      "age"                "from_address"
# [10] "from_city"          "from_state"         "statute_type"
# [13] "statute_code"       "statute_desc"       "counts"
# [16] "case_number"        "arresting_officers" "id"

# %% [markdown]
# We can use the `merge()` function to combine by case number:

# %%
merge_df <- merge(arrests_df2, cases_df, by.x = "case_number", by.y = "casenumber", all=TRUE)

head(merge_df)
# Out:
#   case_number   arrest_date           year.x month.x gender race  ethnicity
# 1 2000-00176967 2020-12-20T17:25:00.0 2020   12      Male   Black NonHispanic
# 2 2002-00017928 2020-02-10T20:50:00.0 2020    2      Male   Black NA
# 3 2002-00084415 2020-06-20T15:00:00.0 2020    6      Male   White Hispanic
# 4 2002-00156155 2020-10-19T21:39:00.0 2020   10      Male   Black NonHispanic
# 5 2009-00012907 2019-07-11T08:00:00.0 2019    7      Male   Black NonHispanic
# 6 2010-00132217 2021-03-17T00:00:00.0 2021    3      Male   Black Hispanic
#   year_of_birth age from_address  ⋯ id                      location
# 1 1960          60  NA            ⋯ pvd5279420904765058610  NA
# 2 1986          33  NA            ⋯ pvd14287653191053962274 NA
# 3 1987          32  MAPLEHURST ST ⋯ pvd3425910849102764874  NA
# 4 1983          36  WILSON ST     ⋯ pvd15553225720158958855 NA
# 5 1979          40  DENISON ST    ⋯ pvd9436840405638425866  NA
# 6 1987          33  RODNEY DR     ⋯ pvd2708776692340882517  NA
#   reported_date month.y year.y offense_desc statute_code.y statute_desc.y
# 1 NA            NA      NA     NA           NA             NA
# 2 NA            NA      NA     NA           NA             NA
# 3 NA            NA      NA     NA           NA             NA
# 4 NA            NA      NA     NA           NA             NA
# 5 NA            NA      NA     NA           NA             NA
# 6 NA            NA      NA     NA           NA             NA
#   counts.y reporting_officer
# 1 NA       NA
# 2 NA       NA
# 3 NA       NA
# 4 NA       NA
# 5 NA       NA
# 6 NA       NA

# %% [markdown]
# - Using `all = TRUE` will fill in blank values as NA whenever a case number is in `arrests_df2` that doesn't exist in `cases_df` and vice versa.
# - Using the `all.x = TRUE` argument will return all values in the first dataframe (`arrests_df2`), as well as any entries with the same ID column(s) from `cases_df`.

# %%
merge(arrests_df2, cases_df, by.x = "case_number", by.y = "casenumber", all.x=TRUE)
# Out:
#       case_number   arrest_date           year.x month.x gender race
# 1     2000-00176967 2020-12-20T17:25:00.0 2020   12      Male   Black
# 2     2002-00017928 2020-02-10T20:50:00.0 2020    2      Male   Black
# 3     2002-00084415 2020-06-20T15:00:00.0 2020    6      Male   White
# 4     2002-00156155 2020-10-19T21:39:00.0 2020   10      Male   Black
# 5     2009-00012907 2019-07-11T08:00:00.0 2019    7      Male   Black
# 6     2010-00132217 2021-03-17T00:00:00.0 2021    3      Male   Black
# 7     2012-00080374 2021-02-27T03:19:00.0 2021    2      Male   Black
# 8     2012-00080374 2021-02-27T03:16:00.0 2021    2      Male   Black
# 9     2012-00080374 2021-02-27T03:16:00.0 2021    2      Male   Black
# 10    2014-00105285 2020-02-09T17:00:00.0 2020    2      Male   White
# 11    2015-00009436 2021-01-20T00:00:00.0 2021    1      Male   Black
# 12    2015-00086936 2019-07-16T00:00:00.0 2019    7      Male   Black
# 13    2016-00083650 2019-09-18T00:00:00.0 2019    9      Male   White
# 14    2017-00008874 2019-10-08T17:01:00.0 2019   10      Male   Black
# 15    2017-00121386 2019-07-11T00:00:00.0 2019    7      Female Black
# 16    2017-00124711 2019-10-25T18:13:00.0 2019   10      Female Black
# 17    2017-00127880 2020-02-25T06:30:00.0 2020    2      Male   Black
# 18    2017-00127880 2020-02-25T06:30:00.0 2020    2      Male   Black
# 19    2017-00136795 2021-04-17T10:42:00.0 2021    4      Male   Black
# 20    2017-00136795 2021-04-17T10:42:00.0 2021    4      Male   Black
# 21    2018-00010222 2020-03-01T19:00:00.0 2020    3      Female White
# 22    2018-00012359 2020-09-06T02:00:00.0 2020    9      Male   Black
# 23    2018-00012359 2020-09-06T02:00:00.0 2020    9      Male   Black
# 24    2018-00014068 2019-10-20T00:00:00.0 2019   10      Male   White
# 25    2018-00014068 2019-10-20T19:39:00.0 2019   10      Male   White
# 26    2018-00020384 2020-08-07T08:00:00.0 2020    8      Female White
# 27    2018-00041521 2019-09-28T00:00:00.0 2019    9      Male   White
# 28    2018-00047016 2019-07-11T17:25:00.0 2019    7      Male   White
# 29    2018-00053407 2020-03-12T18:08:00.0 2020    3      Female Black
# 30    2018-00057707 2019-11-18T00:00:00.0 2019   11      Male   Black
# ⋮     ⋮             ⋮                     ⋮      ⋮       ⋮      ⋮
# 25720 2021-00077370 2021-09-29T20:30:00.0 2021    9      Male   Black
# 25721 2021-00077370 2021-09-29T20:30:00.0 2021    9      Male   Black
# 25722 2021-00077379 2021-09-29T00:00:00.0 2021    9      Female Black
# 25723 2021-00077379 2021-09-29T00:00:00.0 2021    9      Female Black
# 25724 2021-00077379 2021-09-29T00:00:00.0 2021    9      Male   Black
# 25725 2021-00077379 2021-09-29T00:00:00.0 2021    9      Male   Black
# 25726 2021-00077382 2021-09-29T21:12:00.0 2021    9      Male   Black
# 25727 2021-00077407 2021-09-30T00:00:00.0 2021    9      Female White
# 25728 2021-00077542 2021-09-30T15:06:00.0 2021    9      Male   White
# 25729 2021-00077542 2021-09-30T15:06:00.0 2021    9      Male   White
# 25730 2021-00077611 2021-09-30T19:49:00.0 2021    9      Female Black
# 25731 2021-00077653 2021-10-01T00:00:00.0 2021   10      Female White
# 25732 2021-00077653 2021-10-01T00:00:00.0 2021   10      Female White
# 25733 2021-00077653 2021-10-01T00:00:00.0 2021   10      Female White
# 25734 2021-00077653 2021-10-01T00:00:00.0 2021   10      Female White
# 25735 2021-00077653 2021-10-01T00:00:00.0 2021   10      Female White
# 25736 2021-00077653 2021-10-01T00:00:00.0 2021   10      Female White
# 25737 2021-00077653 2021-10-01T00:00:00.0 2021   10      Female White
# 25738 2021-00077653 2021-10-01T00:00:00.0 2021   10      Female White
# 25739 2021-00077653 2021-10-01T00:00:00.0 2021   10      Female White
# 25740 2021-00077653 2021-10-01T00:00:00.0 2021   10      Female White
# 25741 2021-00077653 2021-10-01T00:00:00.0 2021   10      Female White
# 25742 2021-00077653 2021-10-01T00:00:00.0 2021   10      Female White
# 25743 2021-00077653 2021-10-01T00:00:00.0 2021   10      Female White
# 25744 2021-00077653 2021-10-01T00:00:00.0 2021   10      Female White
# 25745 2021-00077653 2021-10-01T00:00:00.0 2021   10      Female White
# 25746 2021-00077653 2021-10-01T00:00:00.0 2021   10      Female White
# 25747 2021-00077654 2021-10-01T00:05:00.0 2021   10      Male   Black
# 25748 2021-00077676 2021-10-01T00:00:00.0 2021   10      Male   Black
# 25749 2021-00501540 2021-08-30T19:54:00.0 2021    8      Female White
#       ethnicity   year_of_birth age from_address             ⋯
# 1     NonHispanic 1960          60  NA                       ⋯
# 2     NA          1986          33  NA                       ⋯
# 3     Hispanic    1987          32  MAPLEHURST ST            ⋯
# 4     NonHispanic 1983          36  WILSON ST                ⋯
# 5     NonHispanic 1979          40  DENISON ST               ⋯
# 6     Hispanic    1987          33  RODNEY DR                ⋯
# 7     NonHispanic 1972          48  GAGE ST                  ⋯
# 8     NonHispanic 1972          48  GAGE ST                  ⋯
# 9     NonHispanic 1972          48  GAGE ST                  ⋯
# 10    Hispanic    1989          30  BROCK AVE                ⋯
# 11    NonHispanic 1976          44  RESERVOIR AVE            ⋯
# 12    NonHispanic 1990          28  GOVERNOR ST              ⋯
# 13    NonHispanic 1983          36  MARTIN ST.               ⋯
# 14    NonHispanic 1991          28  LEAH ST                  ⋯
# 15    NonHispanic 1987          32  PUBLIC ST                ⋯
# 16    NonHispanic 1975          44  ROGER WILLIAMS GREEN AVE ⋯
# 17    NonHispanic 1986          33  ORMS ST                  ⋯
# 18    NonHispanic 1986          33  ORMS ST                  ⋯
# 19    NonHispanic 1965          55  SUFFIX ST                ⋯
# 20    NonHispanic 1965          55  SUFFIX ST                ⋯
# 21    NonHispanic 1973          47  BOURNE AVE               ⋯
# 22    NonHispanic 1990          30  DIGUILIO ST              ⋯
# 23    NonHispanic 1990          30  DIGUILIO ST              ⋯
# 24    NonHispanic 1968          51  CANDACE ST               ⋯
# 25    NonHispanic 1968          51  CANDACE ST               ⋯
# 26    Hispanic    1990          29  PRAIRIE AVE              ⋯
# 27    NonHispanic 1992          27  POST RD                  ⋯
# 28    Hispanic    1995          23  UNKNOWN                  ⋯
# 29    NA          1988          31  RUSSO ST                 ⋯
# 30    Hispanic    1994          25  SACKETT ST               ⋯
# ⋮     ⋮           ⋮             ⋮   ⋮                        ⋱
# 25720 NonHispanic 1965          55  WYATT ST                 ⋯
# 25721 NonHispanic 1965          55  WYATT ST                 ⋯
# 25722 NonHispanic 1961          60  DOUGLAS AVE              ⋯
# 25723 NonHispanic 1961          60  DOUGLAS AVE              ⋯
# 25724 NonHispanic 1954          67  RUSSO ST                 ⋯
# 25725 NonHispanic 1954          67  RUSSO ST                 ⋯
# 25726 NonHispanic 1973          48  ARMISTICE BOULEVARD      ⋯
# 25727 Hispanic    1988          32  WAVERLY ST               ⋯
# 25728 NonHispanic 1990          31  BROAD ST                 ⋯
# 25729 NonHispanic 1990          31  BROAD ST                 ⋯
# 25730 NonHispanic 1964          57  CROSSROADS               ⋯
# 25731 NonHispanic 1979          42  HIGHLAND STREET          ⋯
# 25732 NonHispanic 1979          42  HIGHLAND STREET          ⋯
# 25733 NonHispanic 1979          42  HIGHLAND STREET          ⋯
# 25734 NonHispanic 1979          42  HIGHLAND STREET          ⋯
# 25735 NonHispanic 1979          42  HIGHLAND STREET          ⋯
# 25736 NonHispanic 1979          42  HIGHLAND STREET          ⋯
# 25737 NonHispanic 1979          42  HIGHLAND STREET          ⋯
# 25738 NonHispanic 1979          42  HIGHLAND STREET          ⋯
# 25739 NonHispanic 1979          42  HIGHLAND STREET          ⋯
# 25740 NonHispanic 1979          42  HIGHLAND STREET          ⋯
# 25741 NonHispanic 1979          42  HIGHLAND STREET          ⋯
# 25742 NonHispanic 1979          42  HIGHLAND STREET          ⋯
# 25743 NonHispanic 1979          42  HIGHLAND STREET          ⋯
# 25744 NonHispanic 1979          42  HIGHLAND STREET          ⋯
# 25745 NonHispanic 1979          42  HIGHLAND STREET          ⋯
# 25746 NonHispanic 1979          42  HIGHLAND STREET          ⋯
# 25747 Hispanic    1952          68  PHEBE ST                 ⋯
# 25748 Hispanic    1980          40  No Permanent Address     ⋯
# 25749 NonHispanic 1993          27  COWESETT RD              ⋯
#       id                      location                   reported_date
# 1     pvd5279420904765058610  NA                         NA
# 2     pvd14287653191053962274 NA                         NA
# 3     pvd3425910849102764874  NA                         NA
# 4     pvd15553225720158958855 NA                         NA
# 5     pvd9436840405638425866  NA                         NA
# 6     pvd2708776692340882517  NA                         NA
# 7     pvd5466869003817378838  NA                         NA
# 8     pvd5466869003817378838  NA                         NA
# 9     pvd5466869003817378838  NA                         NA
# 10    pvd16199867161131954743 NA                         NA
# 11    pvd10762340969915704008 NA                         NA
# 12    pvd13795510650322106441 NA                         NA
# 13    pvd2440243512288793200  NA                         NA
# 14    pvd17155851206054325098 NA                         NA
# 15    pvd9512771382099938718  NA                         NA
# 16    pvd4679381590275908009  NA                         NA
# 17    pvd9368867490354895056  NA                         NA
# 18    pvd9368867490354895056  NA                         NA
# 19    pvd803938271178991701   NA                         NA
# 20    pvd803938271178991701   NA                         NA
# 21    pvd2900824132231112636  NA                         NA
# 22    pvd9529058355161842676  NA                         NA
# 23    pvd9529058355161842676  NA                         NA
# 24    pvd17397753801960957126 NA                         NA
# 25    pvd17397753801960957126 NA                         NA
# 26    pvd16135768702340964201 NA                         NA
# 27    pvd2577697737983881494  NA                         NA
# 28    pvd14799321365502983080 NA                         NA
# 29    pvd17137997093794608758 NA                         NA
# 30    pvd17378921621456824298 NA                         NA
# ⋮     ⋮                       ⋮                          ⋮
# 25720 pvd7675372766478296352  HARRISON ST &  DIVISION ST 2021-09-29T20:30:00.0
# 25721 pvd7675372766478296352  HARRISON ST &  DIVISION ST 2021-09-29T20:30:00.0
# 25722 pvd12563331084039738945 880 DOUGLAS AVE            2021-09-29T21:00:00.0
# 25723 pvd12563331084039738945 880 DOUGLAS AVE            2021-09-29T21:00:00.0
# 25724 pvd11372458517369102932 880 DOUGLAS AVE            2021-09-29T21:00:00.0
# 25725 pvd11372458517369102932 880 DOUGLAS AVE            2021-09-29T21:00:00.0
# 25726 pvd1573280805693708985  601 CRANSTON ST            2021-09-29T21:12:00.0
# 25727 pvd6782462755387617562  140 MESSER ST              2021-09-30T00:36:00.0
# 25728 pvd14935609672162974356 160 BROAD ST               2021-09-30T15:06:00.0
# 25729 pvd14935609672162974356 160 BROAD ST               2021-09-30T15:06:00.0
# 25730 pvd10005979167793807438 342 BROAD ST               2021-09-30T19:49:00.0
# 25731 pvd10290435390801352104 18 INKERMAN ST             2021-09-30T23:58:00.0
# 25732 pvd10290435390801352104 18 INKERMAN ST             2021-09-30T23:58:00.0
# 25733 pvd10290435390801352104 18 INKERMAN ST             2021-09-30T23:58:00.0
# 25734 pvd10290435390801352104 18 INKERMAN ST             2021-09-30T23:58:00.0
# 25735 pvd10290435390801352104 18 INKERMAN ST             2021-09-30T23:58:00.0
# 25736 pvd10290435390801352104 18 INKERMAN ST             2021-09-30T23:58:00.0
# 25737 pvd10290435390801352104 18 INKERMAN ST             2021-09-30T23:58:00.0
# 25738 pvd10290435390801352104 18 INKERMAN ST             2021-09-30T23:58:00.0
# 25739 pvd10290435390801352104 18 INKERMAN ST             2021-09-30T23:58:00.0
# 25740 pvd10290435390801352104 18 INKERMAN ST             2021-09-30T23:58:00.0
# 25741 pvd10290435390801352104 18 INKERMAN ST             2021-09-30T23:58:00.0
# 25742 pvd10290435390801352104 18 INKERMAN ST             2021-09-30T23:58:00.0
# 25743 pvd10290435390801352104 18 INKERMAN ST             2021-09-30T23:58:00.0
# 25744 pvd10290435390801352104 18 INKERMAN ST             2021-09-30T23:58:00.0
# 25745 pvd10290435390801352104 18 INKERMAN ST             2021-09-30T23:58:00.0
# 25746 pvd10290435390801352104 18 INKERMAN ST             2021-09-30T23:58:00.0
# 25747 pvd10501230489459422006 10 UNIT ST                 2021-10-01T00:05:00.0
# 25748 pvd6857941429842573728  14 HILLARD ST              2021-10-01T01:12:00.0
# 25749 pvd11811032799571012311 89 SUPERIOR ST             2021-06-02T17:49:25.0
#       month.y year.y offense_desc         statute_code.y
# 1     NA      NA     NA                   NA
# 2     NA      NA     NA                   NA
# 3     NA      NA     NA                   NA
# 4     NA      NA     NA                   NA
# 5     NA      NA     NA                   NA
# 6     NA      NA     NA                   NA
# 7     NA      NA     NA                   NA
# 8     NA      NA     NA                   NA
# 9     NA      NA     NA                   NA
# 10    NA      NA     NA                   NA
# 11    NA      NA     NA                   NA
# 12    NA      NA     NA                   NA
# 13    NA      NA     NA                   NA
# 14    NA      NA     NA                   NA
# 15    NA      NA     NA                   NA
# 16    NA      NA     NA                   NA
# 17    NA      NA     NA                   NA
# 18    NA      NA     NA                   NA
# 19    NA      NA     NA                   NA
# 20    NA      NA     NA                   NA
# 21    NA      NA     NA                   NA
# 22    NA      NA     NA                   NA
# 23    NA      NA     NA                   NA
# 24    NA      NA     NA                   NA
# 25    NA      NA     NA                   NA
# 26    NA      NA     NA                   NA
# 27    NA      NA     NA                   NA
# 28    NA      NA     NA                   NA
# 29    NA      NA     NA                   NA
# 30    NA      NA     NA                   NA
# ⋮     ⋮       ⋮      ⋮                    ⋮
# 25720  9      2021   DUI                  31-27-2.1
# 25721  9      2021   DUI                  31-27-2
# 25722  9      2021   Assault, Simple      11-5-3
# 25723  9      2021   Assault, Simple      11-5-3
# 25724  9      2021   Assault, Simple      11-5-3
# 25725  9      2021   Assault, Simple      11-5-3
# 25726  9      2021   Vandalism            11-44-1
# 25727  9      2021   DUI                  31-27-2
# 25728  9      2021   Assault, Aggravated  11-5-2
# 25729  9      2021   Assault, Aggravated  11-5-2
# 25730  9      2021   Vandalism            11-44-1
# 25731  9      2021   Drug Offenses        21-28-4.01-C1A
# 25732  9      2021   RI Statute Violation 11-32-1
# 25733  9      2021   Disorderly Conduct   11-45-1
# 25734  9      2021   Assault, Simple      11-5-3
# 25735  9      2021   Drug Offenses        21-28-4.01-C1A
# 25736  9      2021   RI Statute Violation 11-32-1
# 25737  9      2021   Disorderly Conduct   11-45-1
# 25738  9      2021   Assault, Simple      11-5-3
# 25739  9      2021   Drug Offenses        21-28-4.01-C1A
# 25740  9      2021   RI Statute Violation 11-32-1
# 25741  9      2021   Disorderly Conduct   11-45-1
# 25742  9      2021   Assault, Simple      11-5-3
# 25743  9      2021   Drug Offenses        21-28-4.01-C1A
# 25744  9      2021   RI Statute Violation 11-32-1
# 25745  9      2021   Disorderly Conduct   11-45-1
# 25746  9      2021   Assault, Simple      11-5-3
# 25747 10      2021   Burglary             11-8-2
# 25748 10      2021   Disorderly Conduct   11-45-1
# 25749  6      2021   Larceny, Other       11-41-1
#       statute_desc.y                                            counts.y
# 1     NA                                                        NA
# 2     NA                                                        NA
# 3     NA                                                        NA
# 4     NA                                                        NA
# 5     NA                                                        NA
# 6     NA                                                        NA
# 7     NA                                                        NA
# 8     NA                                                        NA
# 9     NA                                                        NA
# 10    NA                                                        NA
# 11    NA                                                        NA
# 12    NA                                                        NA
# 13    NA                                                        NA
# 14    NA                                                        NA
# 15    NA                                                        NA
# 16    NA                                                        NA
# 17    NA                                                        NA
# 18    NA                                                        NA
# 19    NA                                                        NA
# 20    NA                                                        NA
# 21    NA                                                        NA
# 22    NA                                                        NA
# 23    NA                                                        NA
# 24    NA                                                        NA
# 25    NA                                                        NA
# 26    NA                                                        NA
# 27    NA                                                        NA
# 28    NA                                                        NA
# 29    NA                                                        NA
# 30    NA                                                        NA
# ⋮     ⋮                                                         ⋮
# 25720 Chemical Test Refusal                                     1
# 25721 Driving Under the Influence of Liqour or Drugs (=>.08<.1) 1
# 25722 SIMPLE ASSAULT/BATTERY                                    1
# 25723 SIMPLE ASSAULT OR BATTERY                                 1
# 25724 SIMPLE ASSAULT/BATTERY                                    1
# 25725 SIMPLE ASSAULT OR BATTERY                                 1
# 25726 VANDALISM/MALICIOUS INJURY TO PROPERTY                    1
# 25727 Driving Under the Influence of Liqour or Drugs (=>.08<.1) 1
# 25728 FELONY ASSAULT/ DANG. WEAPON OR SUBSTANCE                 1
# 25729 FELONY ASSAULT/ DANG. WEAPON OR SUBSTANCE                 2
# 25730 VANDALISM/MALICIOUS INJURY TO PROPERTY                    1
# 25731 POSSESSION OF SCHEDULE I II III                           1
# 25732 OBSTRUCTING OFFICER IN EXECUTION OF DUTY                  1
# 25733 DISORDERLY CONDUCT                                        1
# 25734 SIMPLE ASSAULT OR BATTERY                                 1
# 25735 POSSESSION OF SCHEDULE I II III                           1
# 25736 OBSTRUCTING OFFICER IN EXECUTION OF DUTY                  1
# 25737 DISORDERLY CONDUCT                                        1
# 25738 SIMPLE ASSAULT OR BATTERY                                 1
# 25739 POSSESSION OF SCHEDULE I II III                           1
# 25740 OBSTRUCTING OFFICER IN EXECUTION OF DUTY                  1
# 25741 DISORDERLY CONDUCT                                        1
# 25742 SIMPLE ASSAULT OR BATTERY                                 1
# 25743 POSSESSION OF SCHEDULE I II III                           1
# 25744 OBSTRUCTING OFFICER IN EXECUTION OF DUTY                  1
# 25745 DISORDERLY CONDUCT                                        1
# 25746 SIMPLE ASSAULT OR BATTERY                                 1
# 25747 B&E DWELLING HOUSE W/O CONSENT                            1
# 25748 DISORDERLY CONDUCT                                        1
# 25749 LARCENY/U $1500 - ALL OTH LARCENY                         1
#       reporting_officer
# 1     NA
# 2     NA
# 3     NA
# 4     NA
# 5     NA
# 6     NA
# 7     NA
# 8     NA
# 9     NA
# 10    NA
# 11    NA
# 12    NA
# 13    NA
# 14    NA
# 15    NA
# 16    NA
# 17    NA
# 18    NA
# 19    NA
# 20    NA
# 21    NA
# 22    NA
# 23    NA
# 24    NA
# 25    NA
# 26    NA
# 27    NA
# 28    NA
# 29    NA
# 30    NA
# ⋮     ⋮
# 25720 CVingi
# 25721 CVingi
# 25722 RCriner
# 25723 RCriner
# 25724 RCriner
# 25725 RCriner
# 25726 ALugo
# 25727 KBarth
# 25728 WGeorges
# 25729 WGeorges
# 25730 ALevesque
# 25731 LPrete
# 25732 LPrete
# 25733 LPrete
# 25734 LPrete
# 25735 LPrete
# 25736 LPrete
# 25737 LPrete
# 25738 LPrete
# 25739 LPrete
# 25740 LPrete
# 25741 LPrete
# 25742 LPrete
# 25743 LPrete
# 25744 LPrete
# 25745 LPrete
# 25746 LPrete
# 25747 ESilva
# 25748 SCooney
# 25749 TPickering

# %% [markdown]
# - Using the `all.y = TRUE` argument will return all values in the `cases_df` dataframe, as well as any entries with the same ID column(s) from `arrests_df2`.

# %%
merge(arrests_df2, cases_df, by.x = "case_number", by.y = "casenumber", all.y=TRUE)
# Out:
#       case_number   arrest_date           year.x month.x gender
# 1     2019-00078922 NA                      NA   NA      NA
# 2     2019-00078938 NA                      NA   NA      NA
# 3     2019-00078961 NA                      NA   NA      NA
# 4     2019-00078976 NA                      NA   NA      NA
# 5     2019-00078982 NA                      NA   NA      NA
# 6     2019-00079011 2019-08-11T01:53:00.0 2019    8      Female
# 7     2019-00079015 NA                      NA   NA      NA
# 8     2019-00079020 NA                      NA   NA      NA
# 9     2019-00079028 NA                      NA   NA      NA
# 10    2019-00079032 2019-08-11T02:42:00.0 2019    8      Male
# 11    2019-00079042 NA                      NA   NA      NA
# 12    2019-00079046 NA                      NA   NA      NA
# 13    2019-00079059 2019-08-11T04:45:00.0 2019    8      Male
# 14    2019-00079059 2019-08-11T04:03:00.0 2019    8      Male
# 15    2019-00079073 NA                      NA   NA      NA
# 16    2019-00079078 NA                      NA   NA      NA
# 17    2019-00079094 NA                      NA   NA      NA
# 18    2019-00079097 NA                      NA   NA      NA
# 19    2019-00079103 NA                      NA   NA      NA
# 20    2019-00079108 2019-08-11T10:12:00.0 2019    8      Male
# 21    2019-00079110 NA                      NA   NA      NA
# 22    2019-00079114 NA                      NA   NA      NA
# 23    2019-00079122 2019-08-11T11:28:00.0 2019    8      Male
# 24    2019-00079129 2019-08-11T12:07:00.0 2019    8      Male
# 25    2019-00079140 2019-08-11T12:55:00.0 2019    8      Male
# 26    2019-00079149 NA                      NA   NA      NA
# 27    2019-00079150 NA                      NA   NA      NA
# 28    2019-00079153 2019-08-11T13:22:00.0 2019    8      Male
# 29    2019-00079157 NA                      NA   NA      NA
# 30    2019-00079165 NA                      NA   NA      NA
# ⋮     ⋮             ⋮                     ⋮      ⋮       ⋮
# 54304 2021-00502735 NA                    NA     NA      NA
# 54305 2021-00502736 NA                    NA     NA      NA
# 54306 2021-00502737 NA                    NA     NA      NA
# 54307 2021-00502738 NA                    NA     NA      NA
# 54308 2021-00502739 NA                    NA     NA      NA
# 54309 2021-00502740 NA                    NA     NA      NA
# 54310 2021-00502742 NA                    NA     NA      NA
# 54311 2021-00502743 NA                    NA     NA      NA
# 54312 2021-00502744 NA                    NA     NA      NA
# 54313 2021-00502745 NA                    NA     NA      NA
# 54314 2021-00502746 NA                    NA     NA      NA
# 54315 2021-00502748 NA                    NA     NA      NA
# 54316 2021-00502749 NA                    NA     NA      NA
# 54317 2021-00502750 NA                    NA     NA      NA
# 54318 2021-00502751 NA                    NA     NA      NA
# 54319 2021-00502752 NA                    NA     NA      NA
# 54320 2021-00502753 NA                    NA     NA      NA
# 54321 2021-00502754 NA                    NA     NA      NA
# 54322 2021-00502755 NA                    NA     NA      NA
# 54323 2021-00502756 NA                    NA     NA      NA
# 54324 2021-00502758 NA                    NA     NA      NA
# 54325 2021-00502759 NA                    NA     NA      NA
# 54326 2021-00502760 NA                    NA     NA      NA
# 54327 2021-00502761 NA                    NA     NA      NA
# 54328 2021-00502762 NA                    NA     NA      NA
# 54329 2021-00502763 NA                    NA     NA      NA
# 54330 2021-00502764 NA                    NA     NA      NA
# 54331 2021-00502765 NA                    NA     NA      NA
# 54332 2021-00502766 NA                    NA     NA      NA
# 54333 2021-00502767 NA                    NA     NA      NA
#       race                   ethnicity   year_of_birth age from_address    ⋯
# 1     NA                     NA            NA          NA  NA              ⋯
# 2     NA                     NA            NA          NA  NA              ⋯
# 3     NA                     NA            NA          NA  NA              ⋯
# 4     NA                     NA            NA          NA  NA              ⋯
# 5     NA                     NA            NA          NA  NA              ⋯
# 6     Asian/Pacific Islander NA          1993          26  BARSTOW ST      ⋯
# 7     NA                     NA            NA          NA  NA              ⋯
# 8     NA                     NA            NA          NA  NA              ⋯
# 9     NA                     NA            NA          NA  NA              ⋯
# 10    White                  NA          1997          21  PERRY HILL ROAD ⋯
# 11    NA                     NA            NA          NA  NA              ⋯
# 12    NA                     NA            NA          NA  NA              ⋯
# 13    Black                  Hispanic    1978          40  UNION AVE       ⋯
# 14    NA                     Hispanic    1981          37  WHITTIER AVE    ⋯
# 15    NA                     NA            NA          NA  NA              ⋯
# 16    NA                     NA            NA          NA  NA              ⋯
# 17    NA                     NA            NA          NA  NA              ⋯
# 18    NA                     NA            NA          NA  NA              ⋯
# 19    NA                     NA            NA          NA  NA              ⋯
# 20    White                  Hispanic    1987          31  DORCHESTER AVE  ⋯
# 21    NA                     NA            NA          NA  NA              ⋯
# 22    NA                     NA            NA          NA  NA              ⋯
# 23    Black                  Hispanic    1961          57  GALLUP ST       ⋯
# 24    White                  NA          1959          59  WALLER ST       ⋯
# 25    Black                  NonHispanic 1996          23  BROADWAY        ⋯
# 26    NA                     NA            NA          NA  NA              ⋯
# 27    NA                     NA            NA          NA  NA              ⋯
# 28    Black                  NonHispanic 1976          43  PINE STREET     ⋯
# 29    NA                     NA            NA          NA  NA              ⋯
# 30    NA                     NA            NA          NA  NA              ⋯
# ⋮     ⋮                      ⋮           ⋮             ⋮   ⋮               ⋱
# 54304 NA                     NA          NA            NA  NA              ⋯
# 54305 NA                     NA          NA            NA  NA              ⋯
# 54306 NA                     NA          NA            NA  NA              ⋯
# 54307 NA                     NA          NA            NA  NA              ⋯
# 54308 NA                     NA          NA            NA  NA              ⋯
# 54309 NA                     NA          NA            NA  NA              ⋯
# 54310 NA                     NA          NA            NA  NA              ⋯
# 54311 NA                     NA          NA            NA  NA              ⋯
# 54312 NA                     NA          NA            NA  NA              ⋯
# 54313 NA                     NA          NA            NA  NA              ⋯
# 54314 NA                     NA          NA            NA  NA              ⋯
# 54315 NA                     NA          NA            NA  NA              ⋯
# 54316 NA                     NA          NA            NA  NA              ⋯
# 54317 NA                     NA          NA            NA  NA              ⋯
# 54318 NA                     NA          NA            NA  NA              ⋯
# 54319 NA                     NA          NA            NA  NA              ⋯
# 54320 NA                     NA          NA            NA  NA              ⋯
# 54321 NA                     NA          NA            NA  NA              ⋯
# 54322 NA                     NA          NA            NA  NA              ⋯
# 54323 NA                     NA          NA            NA  NA              ⋯
# 54324 NA                     NA          NA            NA  NA              ⋯
# 54325 NA                     NA          NA            NA  NA              ⋯
# 54326 NA                     NA          NA            NA  NA              ⋯
# 54327 NA                     NA          NA            NA  NA              ⋯
# 54328 NA                     NA          NA            NA  NA              ⋯
# 54329 NA                     NA          NA            NA  NA              ⋯
# 54330 NA                     NA          NA            NA  NA              ⋯
# 54331 NA                     NA          NA            NA  NA              ⋯
# 54332 NA                     NA          NA            NA  NA              ⋯
# 54333 NA                     NA          NA            NA  NA              ⋯
#       id                      location
# 1     NA                      939 DOUGLAS AVE
# 2     NA                      57 EDDY ST
# 3     NA                      380 HOPE ST
# 4     NA                      90 ACADEMY AVE
# 5     NA                      BROAD ST & THURBERS AVE
# 6     pvd9052534029220900662  51 BARSTOW ST
# 7     NA                      CLIFFORD ST & CLAVERICK ST
# 8     NA                      380 HOPE ST
# 9     NA                      772 HOPE ST
# 10    pvd4002343389973320073  172 PINE ST
# 11    NA                      GREENE ST & WESTMINSTER ST
# 12    NA                      43 GOVERNOR ST
# 13    pvd13286858153789230912 571 UNION AVE
# 14    pvd16169810872011370828 571 UNION AVE
# 15    NA                      1 CITIZENS PLZ
# 16    NA                      55 E MANNING ST
# 17    NA                      331 HAWKINS ST
# 18    NA                      114 DOYLE AVE
# 19    NA                      160 BROAD ST
# 20    pvd8433895585399424162  64 DORCHESTER AVE
# 21    NA                      108 HARRIET ST
# 22    NA                      134 MATHEWSON ST
# 23    pvd8852317567007252201  207 GALLUP ST
# 24    pvd18322501737422186882 MT PLEASANT AVE & CHAUCER ST
# 25    pvd17667580711237028630 WARRINGTON ST & NIAGARA ST
# 26    NA                      101 CORINTH ST
# 27    NA                      325 VALLEY ST
# 28    pvd9837197401755700126  315 BROAD ST
# 29    NA                      380 HOPE ST
# 30    NA                      43 HARRISON ST
# ⋮     ⋮                       ⋮
# 54304 NA                      160 ACADEMY AVE
# 54305 NA                      555 VEAZIE ST
# 54306 NA                      801 ELMWOOD AVE AVE
# 54307 NA                      16 WHELAN RD
# 54308 NA                      593 EDDY ST
# 54309 NA                      378 BENEFIT ST
# 54310 NA                      N VEAZIE ST
# 54311 NA                      87 PROSPECT
# 54312 NA                      40 GROVE ST
# 54313 NA                      44 GOVERNOR ST
# 54314 NA                      2 SISSON ST
# 54315 NA                      555 VEAZIE ST
# 54316 NA                      35 PLAINFIELD STREET ST
# 54317 NA                      330 ORMS ST
# 54318 NA                      166 VALLEY ST
# 54319 NA                      137 DOYLE AVE
# 54320 NA                      1 HILTON ST
# 54321 NA                      50 ENCORE CODA LN
# 54322 NA                      1 PROVIDENCE PLACE ST
# 54323 NA                      17 ANDREWS
# 54324 NA                      102 O'CONNELL ST
# 54325 NA                      O'CONNELL ST AND POE ST I
# 54326 NA                      162 O'CONNELL ST PROVIDENCE RI ST
# 54327 NA                      102 O'CONNELL ST
# 54328 NA                      475 EATON ST
# 54329 NA                      128 WHITFORD AVE
# 54330 NA                      86 TOBEY ST
# 54331 NA                      971 BROAD ST
# 54332 NA                      7 PROVIDENCE PL
# 54333 NA                      143 PROVIDENCE PL
#       reported_date         month.y year.y offense_desc
# 1     2019-08-10T23:20:00.0 8       2019   Missing Persons
# 2     2019-08-10T23:36:40.0 8       2019   Request for Assistance
# 3     2019-08-11T00:13:00.0 8       2019   Missing Persons
# 4     2019-08-10T23:49:00.0 8       2019   Assault, Aggravated
# 5     2019-08-11T00:37:00.0 8       2019   Receiving Stolen Property
# 6     2019-08-11T01:53:00.0 8       2019   Assault, Simple
# 7     2019-08-11T02:01:00.0 8       2019   Larceny, Other
# 8     2019-08-11T02:16:00.0 8       2019   Missing Persons
# 9     2019-08-11T02:26:00.0 8       2019   Municipal Code Violation
# 10    2019-08-11T02:42:00.0 8       2019   Disorderly Conduct
# 11    2019-08-11T02:49:00.0 8       2019   Larceny from Motor Vehicle
# 12    2019-08-11T03:04:00.0 8       2019   Burglary
# 13    2019-08-11T04:03:00.0 8       2019   Assault, Aggravated
# 14    2019-08-11T04:03:00.0 8       2019   Assault, Aggravated
# 15    2019-08-11T07:02:50.0 8       2019   Assault, Simple
# 16    2019-08-11T07:40:00.0 8       2019   Burglary
# 17    2019-08-11T08:59:00.0 8       2019   Assistance Rendered
# 18    2019-08-11T09:35:00.0 8       2019   Burglary
# 19    2019-08-11T09:54:00.0 8       2019   Larceny, Other
# 20    2019-08-11T10:12:00.0 8       2019   Assault, Simple
# 21    2019-08-11T10:40:00.0 8       2019   Assault, Simple
# 22    2019-08-11T11:01:00.0 8       2019   Larceny, Other
# 23    2019-08-11T11:28:00.0 8       2019   Assault, Simple
# 24    2019-08-11T12:06:01.0 8       2019   Traffic Violation
# 25    2019-08-11T12:55:00.0 8       2019   Traffic Violation
# 26    2019-08-11T13:10:00.0 8       2019   Vandalism
# 27    2019-08-11T13:15:00.0 8       2019   Fraud, Swindle
# 28    2019-08-11T13:22:00.0 8       2019   Assault, Simple
# 29    2019-08-11T13:40:00.0 8       2019   Missing Persons
# 30    2019-08-11T13:54:00.0 8       2019   Larceny, Other
# ⋮     ⋮                     ⋮       ⋮      ⋮
# 54304 2021-09-29T13:27:34.0  9      2021   RI Statute Violation
# 54305 2021-09-29T16:20:48.0  9      2021   Vandalism
# 54306 2021-09-29T16:54:24.0  9      2021   Fraud, Credit Card
# 54307 2021-09-29T18:48:27.0  9      2021   Vandalism
# 54308 2021-09-29T20:35:11.0  9      2021   Vandalism
# 54309 2021-09-29T20:52:24.0  9      2021   Larceny, Other
# 54310 2021-09-29T21:22:08.0  9      2021   RI Statute Violation
# 54311 2021-09-30T00:57:16.0  9      2021   RI Statute Violation
# 54312 2021-09-30T08:31:59.0  9      2021   Vandalism
# 54313 2021-09-30T10:45:48.0  9      2021   Larceny, Other
# 54314 2021-09-30T10:45:59.0  9      2021   Fraud, Swindle
# 54315 2021-09-30T12:00:47.0  9      2021   Vandalism
# 54316 2021-09-30T12:04:35.0  9      2021   Vandalism
# 54317 2021-09-30T12:21:14.0  9      2021   RI Statute Violation
# 54318 2021-09-30T12:53:32.0  9      2021   Larceny from Motor Vehicle
# 54319 2021-09-30T13:23:14.0  9      2021   Larceny from Motor Vehicle
# 54320 2021-09-30T14:12:52.0  9      2021   Vandalism
# 54321 2021-09-30T15:23:18.0  9      2021   Fraud, Credit Card
# 54322 2021-09-30T17:09:40.0  9      2021   Larceny, Other
# 54323 2021-09-30T17:44:27.0  9      2021   Larceny, Other
# 54324 2021-10-01T01:13:05.0 10      2021   Larceny from Motor Vehicle
# 54325 2021-10-01T06:04:47.0 10      2021   Larceny from Motor Vehicle
# 54326 2021-10-01T06:22:37.0 10      2021   Larceny from Motor Vehicle
# 54327 2021-10-01T06:54:29.0 10      2021   Larceny from Motor Vehicle
# 54328 2021-10-01T06:58:44.0 10      2021   Larceny from Motor Vehicle
# 54329 2021-10-01T08:59:42.0 10      2021   Vandalism
# 54330 2021-10-01T09:12:44.0 10      2021   Larceny from Motor Vehicle
# 54331 2021-10-01T10:18:29.0 10      2021   Fraud, Swindle
# 54332 2021-10-03T16:13:04.0 10      2021   Larceny, Other
# 54333 2021-10-03T18:53:47.0 10      2021   Larceny, Other
#       statute_code.y statute_desc.y
# 1     Not Used       No violations
# 2     Not Used       No violations
# 3     Not Used       No violations
# 4     11-5-2         FELONY ASSAULT/ DANG. WEAPON OR SUBSTANCE
# 5     31-9-2         Possession of Stolen Vehicle or Parts
# 6     11-5-3         SIMPLE ASSAULT/BATTERY
# 7     11-41-1        LARCENY/U $1500 - ALL OTH LARCENY
# 8     Not Used       No violations
# 9     Sec. 16-3.A    Disorderly and indecent conduct A - Theatening
# 10    11-45-1        DISORDERLY CONDUCT
# 11    11-41-1        LARCENY/U $1500 - FROM MV
# 12    11-8-1         BURGLARY
# 13    11-29-1        MUTILITATION OR DISABLING
# 14    11-29-1        MUTILITATION OR DISABLING
# 15    11-5-3         SIMPLE ASSAULT OR BATTERY
# 16    11-8-2         B&E DWELLING HOUSE W/O CONSENT
# 17    Not Used       No violations
# 18    11-8-2         B&E DWELLING HOUSE W/O CONSENT
# 19    11-41-1        LARCENY/U $1500 - ALL OTH LARCENY
# 20    11-5-3         SIMPLE ASSAULT/BATTERY
# 21    11-5-3         SIMPLE ASSAULT OR BATTERY
# 22    11-41-1        LARCENY/U $1500 - ALL OTH LARCENY
# 23    11-5-3         SIMPLE ASSAULT OR BATTERY
# 24    31-10-27       No License on Person - Exhibited on Demand
# 25    31-11-18       Driving after Denial, Suspension or Revocation of License
# 26    11-44-1        VANDALISM/MALICIOUS INJURY TO PROPERTY
# 27    11-49.1-3      IDENTITY FRAUD - FALSE PRETENSE
# 28    11-5-3         SIMPLE ASSAULT OR BATTERY
# 29    Not Used       No violations
# 30    11-41-1        LARCENY/U $1500 - ALL OTH LARCENY
# ⋮     ⋮              ⋮
# 54304 11-35-17       CRANK OR OBSCENE PHONE CALLS - ALL OTH OFFENSE
# 54305 11-44-1        VANDALISM/MALICIOUS INJURY TO PROPERTY
# 54306 11-49-4        FRAUDULENT USE OF CREDIT CARDS
# 54307 11-44-1        VANDALISM/MALICIOUS INJURY TO PROPERTY
# 54308 11-44-1        VANDALISM/MALICIOUS INJURY TO PROPERTY
# 54309 11-41-1        LARCENY/U $1500 - ALL OTH LARCENY
# 54310 11-35-17       CRANK OR OBSCENE PHONE CALLS - ALL OTH OFFENSE
# 54311 11-35-17       CRANK OR OBSCENE PHONE CALLS - ALL OTH OFFENSE
# 54312 11-44-1        VANDALISM/MALICIOUS INJURY TO PROPERTY
# 54313 11-41-1        LARCENY/U $1500 - ALL OTH LARCENY
# 54314 11-49.1-3      IDENTITY FRAUD - FALSE PRETENSE
# 54315 11-44-1        VANDALISM/MALICIOUS INJURY TO PROPERTY
# 54316 11-44-1        VANDALISM/MALICIOUS INJURY TO PROPERTY
# 54317 11-35-17       CRANK OR OBSCENE PHONE CALLS - ALL OTH OFFENSE
# 54318 11-41-1        LARCENY/U $1500 - FROM MV
# 54319 11-41-1        LARCENY/U $1500 - FROM MV
# 54320 11-44-1        VANDALISM/MALICIOUS INJURY TO PROPERTY
# 54321 11-49-4        FRAUDULENT USE OF CREDIT CARDS
# 54322 11-41-1        LARCENY/U $1500 - ALL OTH LARCENY
# 54323 11-41-1        LARCENY/U $1500 - ALL OTH LARCENY
# 54324 11-41-1        LARCENY/U $1500 - FROM MV
# 54325 11-41-1        LARCENY/U $1500 - FROM MV
# 54326 11-41-1        LARCENY/U $1500 - FROM MV
# 54327 11-41-1        LARCENY/U $1500 - FROM MV
# 54328 11-41-1        LARCENY/U $1500 - FROM MV
# 54329 11-44-1        VANDALISM/MALICIOUS INJURY TO PROPERTY
# 54330 11-41-1        LARCENY/U $1500 - FROM MV
# 54331 11-49.1-3      IDENTITY FRAUD - FALSE PRETENSE
# 54332 11-41-1        LARCENY/U $1500 - ALL OTH LARCENY
# 54333 11-41-1        LARCENY/U $1500 - ALL OTH LARCENY
#       counts.y reporting_officer
# 1     0        Central Station
# 2     0        ADaCruz
# 3     0        Central Station
# 4     1        DAnderson
# 5     1        CBrown
# 6     1        NO'Malley
# 7     1        JDennis
# 8     0        Central Station
# 9     1        DGonzalez
# 10    1        JLanier
# 11    1        JDennis
# 12    1        CHines
# 13    1        JPerez
# 14    1        JPerez
# 15    1        TRose
# 16    1        HVentura
# 17    0        MSandorse
# 18    1        JDalton
# 19    1        GSlater
# 20    1        JHeeder
# 21    1        DRosso
# 22    1        GSlater
# 23    1        LBoror
# 24    1        MTella
# 25    1        CBenoit
# 26    1        JBenros
# 27    1        Central Station
# 28    1        WGeorges
# 29    0        Central Station
# 30    1        LPrete
# ⋮     ⋮        ⋮
# 54304 1        TPickering
# 54305 1        TPickering
# 54306 1        TPickering
# 54307 1        TPickering
# 54308 1        TPickering
# 54309 1        TPickering
# 54310 1        TPickering
# 54311 1        TPickering
# 54312 1        TPickering
# 54313 1        TPickering
# 54314 1        TPickering
# 54315 1        TPickering
# 54316 1        TPickering
# 54317 1        TPickering
# 54318 1        TPickering
# 54319 1        TPickering
# 54320 1        TPickering
# 54321 1        TPickering
# 54322 1        TPickering
# 54323 1        TPickering
# 54324 1        TPickering
# 54325 1        TPickering
# 54326 1        TPickering
# 54327 1        TPickering
# 54328 1        TPickering
# 54329 1        TPickering
# 54330 1        TPickering
# 54331 1        BAuclair
# 54332 1        BAuclair
# 54333 1        BAuclair

# %% [markdown]
# What do you notice about this data above? The columns? What's in the rows?

# %% [markdown]
# ## 5.1 Joining instead of merging
#
# There are usually multiple ways to do things in R. A different function for merging exists that is the `join()` family in `tidyverse`:
#
#  * `inner_join(x,y)`: only keeps observations from x that have matching key in y
#  * `left_join(x,y)`: keeps all observations in x
#  * `right_join(x,y)`: keeps all observations in y
#  * `full_join(x,y)`: keeps all observations in x and y
#
#  This family of functions is nice because (1) it allows us to decide which data frame we want to focus on when merging, and (2) it gives more control over how we merge. For example, we can merge multiple columns, specifying which columns should match which columns in each dataframe. When we run `full_join`, we also get some additional information:

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Welcome to the tidyverse!</b>
#
# <a href="https://www.tidyverse.org/"><b>Tidyverse</b></a> is a set of R packages desiend for datascience. All of its packages share an underlying designing philosophy, grammer, and data structures.
#
# Notably in this class we'll be touching on `dplyer`, `ggplot2`, and `reader`.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>INFO!</b>
#
# We already loaded in our csv files with Base R's `read.csv`. We recommend, moving forward to use the following:
#
# `read_csv` from the `readr` package which is included when loading in the `tidyverse` package.
#
# It plays nicer than the base R version and it interprets empty strings as NA values on read by default
#
# <a href="https://readr.tidyverse.org/reference/read_delim.html">See documentation here</a>
#
# </div>

# %%
library(tidyverse)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
full_join(arrests_df2, cases_df, by=join_by(case_number==casenumber,month,year))
# Out:
# Warning message in full_join(arrests_df2, cases_df, by = join_by(case_number == :
# “Detected an unexpected many-to-many relationship between `x` and `y`.
# ℹ Row 2 of `x` matches multiple rows in `y`.
# ℹ Row 6 of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning.”
#       arrest_date           year month gender race  ethnicity   year_of_birth
# 1     2019-08-24T02:23:00.0 2019 8     Male   White NonHispanic 1981
# 2     2019-08-24T02:02:00.0 2019 8     NA     NA    NA          1994
# 3     2019-08-24T02:02:00.0 2019 8     NA     NA    NA          1994
# 4     2019-08-24T02:02:00.0 2019 8     Female Black NonHispanic 1984
# 5     2019-08-24T02:02:00.0 2019 8     Female Black NonHispanic 1984
# 6     2019-08-24T02:02:00.0 2019 8     Female Black NonHispanic 1984
# 7     2019-08-24T02:02:00.0 2019 8     Female Black NonHispanic 1984
# 8     2019-08-24T02:02:00.0 2019 8     Female Black NonHispanic 1984
# 9     2019-08-24T02:02:00.0 2019 8     Female Black NonHispanic 1984
# 10    2019-08-24T02:02:00.0 2019 8     Female Black NonHispanic 1984
# 11    2019-08-24T02:02:00.0 2019 8     Female Black NonHispanic 1984
# 12    2019-08-24T02:02:00.0 2019 8     Female Black NonHispanic 1984
# 13    2019-08-24T02:02:00.0 2019 8     Female Black NonHispanic 1984
# 14    2019-08-24T02:02:00.0 2019 8     Female Black NA          2001
# 15    2019-08-24T02:02:00.0 2019 8     Female Black NA          2001
# 16    2019-08-24T02:02:00.0 2019 8     Female Black NA          2001
# 17    2019-08-24T02:02:00.0 2019 8     Female Black NA          2001
# 18    2019-08-24T02:02:00.0 2019 8     Female Black NA          2001
# 19    2019-08-24T02:02:00.0 2019 8     Female Black NA          2001
# 20    2019-08-24T02:02:00.0 2019 8     Female Black NA          2001
# 21    2019-08-24T02:02:00.0 2019 8     Female Black NA          2001
# 22    2019-08-24T02:02:00.0 2019 8     Female Black NA          2001
# 23    2019-08-24T02:02:00.0 2019 8     Female Black NA          2001
# 24    2019-08-24T02:02:00.0 2019 8     Female Black NA          2001
# 25    2019-08-24T02:02:00.0 2019 8     Female Black NA          2001
# 26    2019-08-24T02:02:00.0 2019 8     Female Black NA          2001
# 27    2019-08-24T02:02:00.0 2019 8     Female Black NA          2001
# 28    2019-08-24T02:02:00.0 2019 8     Female Black NA          2001
# 29    2019-08-23T23:43:00.0 2019 8     Male   Black NonHispanic 1991
# 30    2019-08-23T23:43:00.0 2019 8     Male   Black NonHispanic 1991
# ⋮     ⋮                     ⋮    ⋮     ⋮      ⋮     ⋮           ⋮
# 55685 NA                    2021 10    NA     NA    NA          NA
# 55686 NA                    2021 10    NA     NA    NA          NA
# 55687 NA                    2021 10    NA     NA    NA          NA
# 55688 NA                    2021 10    NA     NA    NA          NA
# 55689 NA                    2021 10    NA     NA    NA          NA
# 55690 NA                    2021 10    NA     NA    NA          NA
# 55691 NA                    2021 10    NA     NA    NA          NA
# 55692 NA                    2021 10    NA     NA    NA          NA
# 55693 NA                    2021 10    NA     NA    NA          NA
# 55694 NA                    2021 10    NA     NA    NA          NA
# 55695 NA                    2021 10    NA     NA    NA          NA
# 55696 NA                    2021 10    NA     NA    NA          NA
# 55697 NA                    2021 10    NA     NA    NA          NA
# 55698 NA                    2021 10    NA     NA    NA          NA
# 55699 NA                    2021  9    NA     NA    NA          NA
# 55700 NA                    2021  9    NA     NA    NA          NA
# 55701 NA                    2021  9    NA     NA    NA          NA
# 55702 NA                    2021  9    NA     NA    NA          NA
# 55703 NA                    2021  9    NA     NA    NA          NA
# 55704 NA                    2021  9    NA     NA    NA          NA
# 55705 NA                    2021  9    NA     NA    NA          NA
# 55706 NA                    2021  9    NA     NA    NA          NA
# 55707 NA                    2021  9    NA     NA    NA          NA
# 55708 NA                    2021  9    NA     NA    NA          NA
# 55709 NA                    2021  9    NA     NA    NA          NA
# 55710 NA                    2021  9    NA     NA    NA          NA
# 55711 NA                    2021  9    NA     NA    NA          NA
# 55712 NA                    2021  9    NA     NA    NA          NA
# 55713 NA                    2021  9    NA     NA    NA          NA
# 55714 NA                    2021  9    NA     NA    NA          NA
#       age from_address         from_city  ⋯ case_number
# 1     37  No Permanent Address providence ⋯ 2019-00084142
# 2     25  SUMMER AVE           Cranston   ⋯ 2019-00084127
# 3     25  SUMMER AVE           Cranston   ⋯ 2019-00084127
# 4     34  DOUGLAS AVE          Providence ⋯ 2019-00084126
# 5     34  DOUGLAS AVE          Providence ⋯ 2019-00084126
# 6     34  DOUGLAS AVE          Providence ⋯ 2019-00084126
# 7     34  DOUGLAS AVE          Providence ⋯ 2019-00084126
# 8     34  DOUGLAS AVE          Providence ⋯ 2019-00084126
# 9     34  DOUGLAS AVE          Providence ⋯ 2019-00084126
# 10    34  DOUGLAS AVE          Providence ⋯ 2019-00084126
# 11    34  DOUGLAS AVE          Providence ⋯ 2019-00084126
# 12    34  DOUGLAS AVE          Providence ⋯ 2019-00084126
# 13    34  DOUGLAS AVE          Providence ⋯ 2019-00084126
# 14    18  TRASH ST             NA         ⋯ 2019-00084126
# 15    18  TRASH ST             NA         ⋯ 2019-00084126
# 16    18  TRASH ST             NA         ⋯ 2019-00084126
# 17    18  TRASH ST             NA         ⋯ 2019-00084126
# 18    18  TRASH ST             NA         ⋯ 2019-00084126
# 19    18  TRASH ST             NA         ⋯ 2019-00084126
# 20    18  TRASH ST             NA         ⋯ 2019-00084126
# 21    18  TRASH ST             NA         ⋯ 2019-00084126
# 22    18  TRASH ST             NA         ⋯ 2019-00084126
# 23    18  TRASH ST             NA         ⋯ 2019-00084126
# 24    18  TRASH ST             NA         ⋯ 2019-00084126
# 25    18  TRASH ST             NA         ⋯ 2019-00084126
# 26    18  TRASH ST             NA         ⋯ 2019-00084126
# 27    18  TRASH ST             NA         ⋯ 2019-00084126
# 28    18  TRASH ST             NA         ⋯ 2019-00084126
# 29    28  PUBLIC ST            Providence ⋯ 2019-00084056
# 30    28  PUBLIC ST            Providence ⋯ 2019-00084056
# ⋮     ⋮   ⋮                    ⋮          ⋱ ⋮
# 55685 NA  NA                   NA         ⋯ 2021-00077850
# 55686 NA  NA                   NA         ⋯ 2021-00077839
# 55687 NA  NA                   NA         ⋯ 2021-00077831
# 55688 NA  NA                   NA         ⋯ 2021-00077827
# 55689 NA  NA                   NA         ⋯ 2021-00077826
# 55690 NA  NA                   NA         ⋯ 2021-00077816
# 55691 NA  NA                   NA         ⋯ 2021-00077809
# 55692 NA  NA                   NA         ⋯ 2021-00077758
# 55693 NA  NA                   NA         ⋯ 2021-00077758
# 55694 NA  NA                   NA         ⋯ 2021-00077755
# 55695 NA  NA                   NA         ⋯ 2021-00077755
# 55696 NA  NA                   NA         ⋯ 2021-00077754
# 55697 NA  NA                   NA         ⋯ 2021-00502765
# 55698 NA  NA                   NA         ⋯ 2021-00077661
# 55699 NA  NA                   NA         ⋯ 2021-00077631
# 55700 NA  NA                   NA         ⋯ 2021-00077629
# 55701 NA  NA                   NA         ⋯ 2021-00077491
# 55702 NA  NA                   NA         ⋯ 2021-00077413
# 55703 NA  NA                   NA         ⋯ 2021-00502710
# 55704 NA  NA                   NA         ⋯ 2021-00502709
# 55705 NA  NA                   NA         ⋯ 2021-00076717
# 55706 NA  NA                   NA         ⋯ 2021-00076473
# 55707 NA  NA                   NA         ⋯ 2021-00076473
# 55708 NA  NA                   NA         ⋯ 2021-00076473
# 55709 NA  NA                   NA         ⋯ 2021-00076473
# 55710 NA  NA                   NA         ⋯ 2021-00076473
# 55711 NA  NA                   NA         ⋯ 2021-00076473
# 55712 NA  NA                   NA         ⋯ 2021-00076473
# 55713 NA  NA                   NA         ⋯ 2021-00502672
# 55714 NA  NA                   NA         ⋯ 2021-00502671
#       arresting_officers       id
# 1      YGonzalez, LTaveras     pvd2218242150382148273
# 2      NManfredi               pvd15166785558364246202
# 3      NManfredi               pvd15166785558364246202
# 4      MPlace, JPerez, ASantos pvd3142917706201385905
# 5      MPlace, JPerez, ASantos pvd3142917706201385905
# 6      MPlace, JPerez, ASantos pvd3142917706201385905
# 7      MPlace, JPerez, ASantos pvd3142917706201385905
# 8      MPlace, JPerez, ASantos pvd3142917706201385905
# 9      MPlace, JPerez, ASantos pvd3142917706201385905
# 10     MPlace, JPerez, ASantos pvd3142917706201385905
# 11     MPlace, JPerez, ASantos pvd3142917706201385905
# 12     MPlace, JPerez, ASantos pvd3142917706201385905
# 13     MPlace, JPerez, ASantos pvd3142917706201385905
# 14     MPlace, JPerez, ASantos pvd460449304532374599
# 15     MPlace, JPerez, ASantos pvd460449304532374599
# 16     MPlace, JPerez, ASantos pvd460449304532374599
# 17     MPlace, JPerez, ASantos pvd460449304532374599
# 18     MPlace, JPerez, ASantos pvd460449304532374599
# 19     MPlace, JPerez, ASantos pvd460449304532374599
# 20     MPlace, JPerez, ASantos pvd460449304532374599
# 21     MPlace, JPerez, ASantos pvd460449304532374599
# 22     MPlace, JPerez, ASantos pvd460449304532374599
# 23     MPlace, JPerez, ASantos pvd460449304532374599
# 24     MPlace, JPerez, ASantos pvd460449304532374599
# 25     MPlace, JPerez, ASantos pvd460449304532374599
# 26     MPlace, JPerez, ASantos pvd460449304532374599
# 27     MPlace, JPerez, ASantos pvd460449304532374599
# 28     MPlace, JPerez, ASantos pvd460449304532374599
# 29     CVingi, SCooney         pvd6431558757894418021
# 30     CVingi, SCooney         pvd6431558757894418021
# ⋮     ⋮                        ⋮
# 55685 NA                       NA
# 55686 NA                       NA
# 55687 NA                       NA
# 55688 NA                       NA
# 55689 NA                       NA
# 55690 NA                       NA
# 55691 NA                       NA
# 55692 NA                       NA
# 55693 NA                       NA
# 55694 NA                       NA
# 55695 NA                       NA
# 55696 NA                       NA
# 55697 NA                       NA
# 55698 NA                       NA
# 55699 NA                       NA
# 55700 NA                       NA
# 55701 NA                       NA
# 55702 NA                       NA
# 55703 NA                       NA
# 55704 NA                       NA
# 55705 NA                       NA
# 55706 NA                       NA
# 55707 NA                       NA
# 55708 NA                       NA
# 55709 NA                       NA
# 55710 NA                       NA
# 55711 NA                       NA
# 55712 NA                       NA
# 55713 NA                       NA
# 55714 NA                       NA
#       location                  reported_date
# 1     46 GESLER ST              2019-08-24T02:23:00.0
# 2     1095 EDDY ST              2019-08-24T02:02:00.0
# 3     1095 EDDY ST              2019-08-24T02:02:00.0
# 4     60 HARTFORD AVE           2019-08-24T02:02:00.0
# 5     60 HARTFORD AVE           2019-08-24T02:02:00.0
# 6     60 HARTFORD AVE           2019-08-24T02:02:00.0
# 7     60 HARTFORD AVE           2019-08-24T02:02:00.0
# 8     60 HARTFORD AVE           2019-08-24T02:02:00.0
# 9     60 HARTFORD AVE           2019-08-24T02:02:00.0
# 10    60 HARTFORD AVE           2019-08-24T02:02:00.0
# 11    60 HARTFORD AVE           2019-08-24T02:02:00.0
# 12    60 HARTFORD AVE           2019-08-24T02:02:00.0
# 13    60 HARTFORD AVE           2019-08-24T02:02:00.0
# 14    60 HARTFORD AVE           2019-08-24T02:02:00.0
# 15    60 HARTFORD AVE           2019-08-24T02:02:00.0
# 16    60 HARTFORD AVE           2019-08-24T02:02:00.0
# 17    60 HARTFORD AVE           2019-08-24T02:02:00.0
# 18    60 HARTFORD AVE           2019-08-24T02:02:00.0
# 19    60 HARTFORD AVE           2019-08-24T02:02:00.0
# 20    60 HARTFORD AVE           2019-08-24T02:02:00.0
# 21    60 HARTFORD AVE           2019-08-24T02:02:00.0
# 22    60 HARTFORD AVE           2019-08-24T02:02:00.0
# 23    60 HARTFORD AVE           2019-08-24T02:02:00.0
# 24    60 HARTFORD AVE           2019-08-24T02:02:00.0
# 25    60 HARTFORD AVE           2019-08-24T02:02:00.0
# 26    60 HARTFORD AVE           2019-08-24T02:02:00.0
# 27    60 HARTFORD AVE           2019-08-24T02:02:00.0
# 28    60 HARTFORD AVE           2019-08-24T02:02:00.0
# 29    BROAD ST & COMSTOCK AVE   2019-08-23T23:15:00.0
# 30    BROAD ST & COMSTOCK AVE   2019-08-23T23:15:00.0
# ⋮     ⋮                         ⋮
# 55685 145 DONELSON ST           2021-10-01T16:06:00.0
# 55686 48 HELME ST               2021-10-01T15:53:00.0
# 55687 64 DARTMOUTH AVE          2021-10-01T15:36:00.0
# 55688 25 SALMON ST              2021-10-01T15:24:00.0
# 55689 325 WASHINGTON ST         2021-10-01T15:22:00.0
# 55690 11 VILLA AVE              2021-10-01T14:57:00.0
# 55691 46 ROSEDALE ST            2021-10-01T14:22:11.0
# 55692 58 DEPASQUALE AVE         2021-10-01T11:09:00.0
# 55693 58 DEPASQUALE AVE         2021-10-01T11:09:00.0
# 55694 267 HARTFORD AVE          2021-10-01T10:58:00.0
# 55695 267 HARTFORD AVE          2021-10-01T10:58:00.0
# 55696 812 BRANCH AVE            2021-10-01T10:34:42.0
# 55697 971 BROAD ST              2021-10-01T10:18:29.0
# 55698 EATON ST &  PINEHURST AVE 2021-10-01T00:24:00.0
# 55699 145 DONELSON ST           2021-09-30T21:45:00.0
# 55700 48 PLAINFIELD ST          2021-09-30T21:26:00.0
# 55701 530 BROADWAY              2021-09-30T11:26:00.0
# 55702 525 CHALKSTONE AVE        2021-09-30T01:38:00.0
# 55703 299 CARPENTER ST          2021-09-27T16:42:04.0
# 55704 168 PROVIDENCE PL         2021-09-27T16:26:25.0
# 55705 329 IVES ST               2021-09-27T16:00:00.0
# 55706 333 ATWELLS AVE           2021-09-26T21:49:00.0
# 55707 333 ATWELLS AVE           2021-09-26T21:49:00.0
# 55708 333 ATWELLS AVE           2021-09-26T21:49:00.0
# 55709 333 ATWELLS AVE           2021-09-26T21:49:00.0
# 55710 333 ATWELLS AVE           2021-09-26T21:49:00.0
# 55711 333 ATWELLS AVE           2021-09-26T21:49:00.0
# 55712 333 ATWELLS AVE           2021-09-26T21:49:00.0
# 55713 15 THIRD STREET ST        2021-09-24T19:47:15.0
# 55714 812 BRANCH AVE            2021-09-24T17:43:55.0
#       offense_desc               statute_code.y
# 1     RI Statute Violation       12-9-16
# 2     Traffic Violation          31-3-32
# 3     Traffic Violation          31-11-18
# 4     Disorderly Conduct         11-45-1
# 5     RI Statute Violation       11-32-1
# 6     Warrant\\Capias            BWARRANT-6D
# 7     RI Statute Violation       12-7-10
# 8     RI Statute Violation       12-9-16
# 9     Disorderly Conduct         11-45-1
# 10    RI Statute Violation       11-32-1
# 11    Warrant\\Capias            BWARRANT-6D
# 12    RI Statute Violation       12-7-10
# 13    RI Statute Violation       12-9-16
# 14    Disorderly Conduct         11-45-1
# 15    RI Statute Violation       11-32-1
# 16    Warrant\\Capias            BWARRANT-6D
# 17    RI Statute Violation       12-7-10
# 18    RI Statute Violation       12-9-16
# 19    Disorderly Conduct         11-45-1
# 20    RI Statute Violation       11-32-1
# 21    Warrant\\Capias            BWARRANT-6D
# 22    RI Statute Violation       12-7-10
# 23    RI Statute Violation       12-9-16
# 24    Disorderly Conduct         11-45-1
# 25    RI Statute Violation       11-32-1
# 26    Warrant\\Capias            BWARRANT-6D
# 27    RI Statute Violation       12-7-10
# 28    RI Statute Violation       12-9-16
# 29    Drug Offenses              21-28-4.01-C2-(iii)
# 30    Traffic Violation          31-11-18
# ⋮     ⋮                          ⋮
# 55685 RI Statute Violation       15-15-3
# 55686 Larceny, Other             11-41-1
# 55687 Missing Persons            Not Used
# 55688 Assault, Simple            11-5-3
# 55689 Motor Vehicle Theft        11-41-1
# 55690 Suspicious Person          Not Used
# 55691 Disorderly Conduct         11-45-1
# 55692 Assault, Simple            11-5-3
# 55693 RI Statute Violation       11-35-14
# 55694 Assault, Simple            11-5-3
# 55695 Larceny, Other             11-41-1
# 55696 Larceny from Building      11-41-1
# 55697 Fraud, Swindle             11-49.1-3
# 55698 Robbery                    11-39-1
# 55699 Disorderly Conduct         11-45-1
# 55700 Larceny, Other             11-41-1
# 55701 Larceny from Motor Vehicle 11-41-1
# 55702 City Ordinance Violation   Not Used
# 55703 Larceny, Other             11-41-1
# 55704 Larceny, Other             11-41-1
# 55705 Request for Assistance     Not Used
# 55706 Forgery                    11-47-3.2-B
# 55707 Weapons                    11-47-8-A
# 55708 Weapons                    11-47-24
# 55709 Weapons                    11-47-5
# 55710 Weapons                    11-47-50
# 55711 Assault, Aggravated        11-5-1
# 55712 Assault, Aggravated        11-5-2
# 55713 Vandalism                  11-44-1
# 55714 Larceny from Motor Vehicle 11-41-1
#       statute_desc.y                                              counts.y
# 1     WARRANT OF ARREST ON AFFIDAVIT - ALL OTH OFFENSE            1
# 2     Driving with Expired Registration                           1
# 3     Driving after Denial, Suspension or Revocation of License   1
# 4     DISORDERLY CONDUCT                                          3
# 5     OBSTRUCTING OFFICER IN EXECUTION OF DUTY                    1
# 6     BENCH WARRANT ISSUED FROM 6TH DISTRICT COURT                1
# 7     RESISTING LEGAL OR ILLEGAL ARREST                           3
# 8     WARRANT OF ARREST ON AFFIDAVIT - ALL OTH OFFENSE            4
# 9     DISORDERLY CONDUCT                                          3
# 10    OBSTRUCTING OFFICER IN EXECUTION OF DUTY                    1
# 11    BENCH WARRANT ISSUED FROM 6TH DISTRICT COURT                1
# 12    RESISTING LEGAL OR ILLEGAL ARREST                           3
# 13    WARRANT OF ARREST ON AFFIDAVIT - ALL OTH OFFENSE            4
# 14    DISORDERLY CONDUCT                                          3
# 15    OBSTRUCTING OFFICER IN EXECUTION OF DUTY                    1
# 16    BENCH WARRANT ISSUED FROM 6TH DISTRICT COURT                1
# 17    RESISTING LEGAL OR ILLEGAL ARREST                           3
# 18    WARRANT OF ARREST ON AFFIDAVIT - ALL OTH OFFENSE            4
# 19    DISORDERLY CONDUCT                                          3
# 20    OBSTRUCTING OFFICER IN EXECUTION OF DUTY                    1
# 21    BENCH WARRANT ISSUED FROM 6TH DISTRICT COURT                1
# 22    RESISTING LEGAL OR ILLEGAL ARREST                           3
# 23    WARRANT OF ARREST ON AFFIDAVIT - ALL OTH OFFENSE            4
# 24    DISORDERLY CONDUCT                                          3
# 25    OBSTRUCTING OFFICER IN EXECUTION OF DUTY                    1
# 26    BENCH WARRANT ISSUED FROM 6TH DISTRICT COURT                1
# 27    RESISTING LEGAL OR ILLEGAL ARREST                           3
# 28    WARRANT OF ARREST ON AFFIDAVIT - ALL OTH OFFENSE            4
# 29    POSSESSION OF MARIJUANA 1OZ OR LESS OVER 18 YEARS OF AGE    1
# 30    Driving after Denial, Suspension or Revocation of License   1
# ⋮     ⋮                                                           ⋮
# 55685 VIOLATION OF PROTECTIVE ORDER                               1
# 55686 LARCENY/U $1500 - ALL OTH LARCENY                           1
# 55687 No violations                                               0
# 55688 SIMPLE ASSAULT/BATTERY                                      1
# 55689 LARCENY/U $1500 - AUTO THEFT                                1
# 55690 No violations                                               0
# 55691 DISORDERLY CONDUCT                                          1
# 55692 SIMPLE ASSAULT/BATTERY                                      1
# 55693 REFUSE/RELINQUISH TELEPHONE - W/O DAMAGE                    1
# 55694 SIMPLE ASSAULT/BATTERY                                      1
# 55695 LARCENY/U $1500 - ALL OTH LARCENY                           1
# 55696 LARCENY/O $1500 - FROM BLD                                  1
# 55697 IDENTITY FRAUD - FALSE PRETENSE                             1
# 55698 ROBBERY-1ST DEGREE                                          1
# 55699 DISORDERLY CONDUCT                                          1
# 55700 LARCENY/U $1500 - ALL OTH LARCENY                           1
# 55701 LARCENY/O $1500 - FROM MV                                   1
# 55702 No violations                                               0
# 55703 LARCENY/U $1500 - ALL OTH LARCENY                           1
# 55704 LARCENY/U $1500 - ALL OTH LARCENY                           1
# 55705 No violations                                               0
# 55706 DISCHARGE OF FA WHILE COMMITTING CRIME OF VIOLENCE          1
# 55707 LICENSE OR PERMIT REQUIRED FOR CARRYING PISTOL              1
# 55708 ALTER OF MARKS OF IDENTIFICATION ON A FIREARM - WEAPON VIOL 1
# 55709 POSS OF ARMS BY CONVICT IN CRIME OF VIOL/FUGITIVE           1
# 55710 FIRING IN COMPACT AREA                                      1
# 55711 ASSAULT W/ INTENT TO COMMIT A FELONY - SERIOUS INJURY       1
# 55712 FELONY ASSAULT/ DANG. WEAPON OR SUBSTANCE                   2
# 55713 VANDALISM/MALICIOUS INJURY TO PROPERTY                      1
# 55714 LARCENY/U $1500 - FROM MV                                   1
#       reporting_officer
# 1     LTaveras
# 2     NManfredi
# 3     NManfredi
# 4     MPlace
# 5     MPlace
# 6     MPlace
# 7     MPlace
# 8     MPlace
# 9     MPlace
# 10    MPlace
# 11    MPlace
# 12    MPlace
# 13    MPlace
# 14    MPlace
# 15    MPlace
# 16    MPlace
# 17    MPlace
# 18    MPlace
# 19    MPlace
# 20    MPlace
# 21    MPlace
# 22    MPlace
# 23    MPlace
# 24    MPlace
# 25    MPlace
# 26    MPlace
# 27    MPlace
# 28    MPlace
# 29    CVingi
# 30    CVingi
# ⋮     ⋮
# 55685 TCalandra
# 55686 Central Station
# 55687 Central Station
# 55688 Central Station
# 55689 Central Station
# 55690 PHourahan
# 55691 LFernandez
# 55692 ITavarez
# 55693 ITavarez
# 55694 YGonzalez
# 55695 YGonzalez
# 55696 JMadeira
# 55697 BAuclair
# 55698 TCalandra
# 55699 TCalandra
# 55700 RMalloy
# 55701 PCaminero
# 55702 DImpagliazzo
# 55703 TPickering
# 55704 TPickering
# 55705 LPelaez
# 55706 ITorres
# 55707 ITorres
# 55708 ITorres
# 55709 ITorres
# 55710 ITorres
# 55711 ITorres
# 55712 ITorres
# 55713 TPickering
# 55714 TPickering

# %%
arrests_df2[2,]
# Out:
#   arrest_date           year month gender race ethnicity year_of_birth age
# 2 2019-08-24T02:02:00.0 2019 8     NA     NA   NA        1994          25
#   from_address from_city from_state   statute_type         statute_code
# 2 SUMMER AVE   Cranston  Rhode Island RI Statute Violation 31-11-18
#   statute_desc                                              counts
# 2 Driving after Denial, Suspension or Revocation of License 1
#   case_number   arresting_officers id
# 2 2019-00084127  NManfredi         pvd15166785558364246202

# %% [markdown]
# # 6. The _dplyr_ Package
#
#   - "dplyr" is short for "data plyer"
#   - R package for aggregating, summarizing, reshaping, and generally wrangling data
#   - Extremely popular in the R community
#   - Authored by Hadley Wickham
#   - Part of the "tidyverse" set of packages
#    - We have already loaded "tidyverse", so we don't need to load any more packages for it

# %% [markdown]
# ## 6.1 The _dplyr_ Verbs
#
#   - The _dplyr_ package is organized around a set of "verbs", which are functions that operate on data
#     + `filter()` - function is used to subset a data frame, retaining all rows that satisfies your conditions
#     + `summarise()` - creates a new data frame. It returns one row for each combination of grouping variables.
#     + `select()` - selects variables in a data frame
#     + `mutate()` - creates new columns that are functions of existing variables
#     + `arrange()` - orders the rows of a data frame by the values of selected columns

# %% [markdown]
# ## 6.2 The Pipe Operator
#
#   - Can be used to pipe some object into a function call
#   - `%>%`
#     + `x %>% f(y)` is the same as `f(x, y)`

# %% [markdown]
# # 7. `filter()` Examples with _dplyr_

# %%
cases_df %>% 
    filter(casenumber=='2019-00084127')
# Out:
#   casenumber    location     reported_date         month year offense_desc
# 1 2019-00084127 1095 EDDY ST 2019-08-24T02:02:00.0 8     2019 Traffic Violation
# 2 2019-00084127 1095 EDDY ST 2019-08-24T02:02:00.0 8     2019 Traffic Violation
#   statute_code statute_desc                                              counts
# 1 31-3-32      Driving with Expired Registration                         1
# 2 31-11-18     Driving after Denial, Suspension or Revocation of License 1
#   reporting_officer
# 1 NManfredi
# 2 NManfredi

# %% [markdown]
# ### 7.1.1 Comparing `filter()` with Logical Indexing

# %%
# dplyr approach
cases_df %>% 
    filter(casenumber=='2019-00084127')


# "base" R approach
weird_case <- cases_df$casenumber == "2019-00084127"      # create vector of bools

cases_df[weird_case, ]                       # get cases with that casenumber
# Out:
#   casenumber    location     reported_date         month year offense_desc
# 1 2019-00084127 1095 EDDY ST 2019-08-24T02:02:00.0 8     2019 Traffic Violation
# 2 2019-00084127 1095 EDDY ST 2019-08-24T02:02:00.0 8     2019 Traffic Violation
#   statute_code statute_desc                                              counts
# 1 31-3-32      Driving with Expired Registration                         1
# 2 31-11-18     Driving after Denial, Suspension or Revocation of License 1
#   reporting_officer
# 1 NManfredi
# 2 NManfredi
#   casenumber    location     reported_date         month year offense_desc
# 5 2019-00084127 1095 EDDY ST 2019-08-24T02:02:00.0 8     2019 Traffic Violation
# 9 2019-00084127 1095 EDDY ST 2019-08-24T02:02:00.0 8     2019 Traffic Violation
#   statute_code statute_desc                                              counts
# 5 31-3-32      Driving with Expired Registration                         1
# 9 31-11-18     Driving after Denial, Suspension or Revocation of License 1
#   reporting_officer
# 5 NManfredi
# 9 NManfredi

# %% [markdown]
# ## 7.2 `filter()` Examples (cont.)

# %%
# Here we create a new data.frame from result of filter()

arrests_males <- arrests_df %>% 
    filter(gender == "Male")

# %%
head(arrests_males)
# Out:
#   arrest_date           year month gender race  ethnicity   year_of_birth age
# 1 2019-08-24T02:23:00.0 2019 8     Male   White NonHispanic 1981          37
# 2 2019-08-23T23:43:00.0 2019 8     Male   Black NonHispanic 1991          28
# 3 2019-08-23T23:43:00.0 2019 8     Male   Black NonHispanic 1991          28
# 4 2019-08-23T23:43:00.0 2019 8     Male   Black NonHispanic 1991          28
# 5 2019-08-23T21:38:00.0 2019 8     Male   White Hispanic    1996          22
# 6 2019-08-23T19:50:00.0 2019 8     Male   White Hispanic    2000          19
#   from_address         from_city  from_state   statute_type
# 1 No Permanent Address providence Rhode Island
# 2 PUBLIC ST            Providence              RI Statute Violation
# 3 PUBLIC ST            Providence              RI Statute Violation
# 4 PUBLIC ST            Providence              RI Statute Violation
# 5 DOUGLAS              Providence              RI Statute Violation
# 6 MOWRY ST             Providence              RI Statute Violation
#   statute_code statute_desc                                              counts
# 1                                                                        NA
# 2 31-27-2.1    Chemical Test Refusal                                      1
# 3 31-27-2      Driving Under the Influence of Liqour or Drugs (=>.08<.1)  1
# 4 31-11-18     Driving after Denial, Suspension or Revocation of License  1
# 5 11-44-1      DOMESTIC-VANDALISM/MALICIOUS INJURY TO PROP                1
# 6 31-27-4      Reckless Driving, Drag Racing - Attempting to Elude        1
#   case_number   arresting_officers   id
# 1 2019-00084142  YGonzalez, LTaveras pvd2218242150382148273
# 2 2019-00084056  CVingi, SCooney     pvd6431558757894418021
# 3 2019-00084056  CVingi, SCooney     pvd6431558757894418021
# 4 2019-00084056  CVingi, SCooney     pvd6431558757894418021
# 5 2019-00084031  RCarlin, SKennedy   pvd15614289459563584867
# 6 2019-00083996  SCampbell, RMalloy  pvd900460037611487829

# %% [markdown]
# ## 7.2 Using `filter()` with Multiple Conditions

# %%
arrests_teen_male <- arrests_df %>%
    filter(
        gender == "Male",
        age < 20
    )

arrests_teen_male
# Out:
#     arrest_date           year month gender race    ethnicity   year_of_birth
# 1   2019-08-23T19:50:00.0 2019 8     Male   White   Hispanic    2000
# 2   2019-08-23T19:50:00.0 2019 8     Male   White   Hispanic    2000
# 3   2019-08-21T13:09:00.0 2019 8     Male   White   Hispanic    1999
# 4   2019-08-21T13:09:00.0 2019 8     Male   White   Hispanic    1999
# 5   2019-08-21T13:09:00.0 2019 8     Male   White   Hispanic    1999
# 6   2019-08-20T02:00:00.0 2019 8     Male   White   Hispanic    1999
# 7   2019-08-20T00:00:00.0 2019 8     Male   Black   NonHispanic 2000
# 8   2019-08-17T00:00:00.0 2019 8     Male   White   Hispanic    2001
# 9   2019-08-15T18:12:00.0 2019 8     Male   Black   NonHispanic 2000
# 10  2019-08-15T00:00:00.0 2019 8     Male   Black   Hispanic    2000
# 11  2019-08-15T00:00:00.0 2019 8     Male   Black               2000
# 12  2019-08-14T23:59:00.0 2019 8     Male   Black   NonHispanic 2001
# 13  2019-08-14T22:15:00.0 2019 8     Male   Black   Hispanic    2000
# 14  2019-08-14T00:44:00.0 2019 8     Male   White   Hispanic    2000
# 15  2019-08-14T00:44:00.0 2019 8     Male   Black   Hispanic    1999
# 16  2019-08-09T15:23:00.0 2019 8     Male   Black   Hispanic    2000
# 17  2019-08-09T00:41:00.0 2019 8     Male   Black   NonHispanic 2000
# 18  2019-08-08T23:02:00.0 2019 8     Male   Black   NonHispanic 2000
# 19  2019-08-08T23:02:00.0 2019 8     Male   Black   NonHispanic 2000
# 20  2019-08-08T23:02:00.0 2019 8     Male   White   NonHispanic 2000
# 21  2019-08-08T23:02:00.0 2019 8     Male   White   NonHispanic 2000
# 22  2019-08-06T09:47:00.0 2019 8     Male   White   Hispanic    1999
# 23  2019-08-06T00:57:00.0 2019 8     Male   White   Hispanic    2000
# 24  2019-07-31T18:55:00.0 2019 7     Male   Black   NonHispanic 1999
# 25  2019-07-31T14:28:00.0 2019 7     Male   White   Hispanic    2000
# 26  2019-07-30T19:39:00.0 2019 7     Male   Black   NonHispanic 2001
# 27  2019-07-30T19:39:00.0 2019 7     Male   Black   NonHispanic 2001
# 28  2019-07-30T19:39:00.0 2019 7     Male   Unknown Unknown     2000
# 29  2019-07-29T15:28:00.0 2019 7     Male   Black               1999
# 30  2019-07-28T12:51:00.0 2019 7     Male   Black   Hispanic    1999
# ⋮   ⋮                     ⋮    ⋮     ⋮      ⋮       ⋮           ⋮
# 565 2021-08-11T16:01:00.0 2021 8     Male   White   NonHispanic 2001
# 566 2021-08-21T00:00:00.0 2021 8     Male   White   NonHispanic 2002
# 567 2021-08-26T09:00:00.0 2021 8     Male   Black   NonHispanic 2001
# 568 2021-08-26T09:00:00.0 2021 8     Male   Black   NonHispanic 2001
# 569 2021-08-26T09:00:00.0 2021 8     Male   Black   NonHispanic 2001
# 570 2021-08-26T09:00:00.0 2021 8     Male   Black   NonHispanic 2001
# 571 2021-08-28T02:40:00.0 2021 8     Male   Black   NonHispanic 2002
# 572 2021-08-28T02:40:00.0 2021 8     Male   Black   NonHispanic 2002
# 573 2021-08-30T14:11:00.0 2021 8     Male   Black   NonHispanic 2002
# 574 2021-09-05T00:00:00.0 2021 9     Male   White   NonHispanic 2001
# 575 2021-09-05T00:00:00.0 2021 9     Male   Black   NonHispanic 2003
# 576 2021-09-03T00:00:00.0 2021 9     Male   Unknown NonHispanic 2001
# 577 2021-09-02T22:15:00.0 2021 9     Male   White   NonHispanic 2002
# 578 2021-09-02T22:15:00.0 2021 9     Male   White   NonHispanic 2001
# 579 2021-09-02T22:15:00.0 2021 9     Male   White   NonHispanic 2001
# 580 2021-09-01T11:47:00.0 2021 9     Male   Black   NonHispanic 2003
# 581 2021-09-09T23:22:00.0 2021 9     Male   Black   NonHispanic 2002
# 582 2021-09-11T23:10:00.0 2021 9     Male   White   NonHispanic 2001
# 583 2021-09-11T23:42:00.0 2021 9     Male   White   NonHispanic 2002
# 584 2021-09-12T00:12:00.0 2021 9     Male   White   NonHispanic 2002
# 585 2021-09-11T23:59:00.0 2021 9     Male   White   NonHispanic 2002
# 586 2021-09-14T15:42:00.0 2021 9     Male   Black   NonHispanic 2002
# 587 2021-09-15T21:15:00.0 2021 9     Male   Black   NonHispanic 2001
# 588 2021-09-18T19:25:00.0 2021 9     Male   White   NonHispanic 2002
# 589 2021-09-21T11:30:00.0 2021 9     Male   Black   NonHispanic 2003
# 590 2021-09-21T11:30:00.0 2021 9     Male   Black   NonHispanic 2003
# 591 2021-09-21T11:30:00.0 2021 9     Male   Black   NonHispanic 2003
# 592 2021-09-21T11:30:00.0 2021 9     Male   Black   NonHispanic 2003
# 593 2021-09-22T16:17:00.0 2021 9     Male   Black   NonHispanic 2001
# 594 2021-09-28T22:33:00.0 2021 9     Male   Black   NonHispanic 2002
#     age from_address         from_city            from_state
# 1   19  MOWRY ST             Providence
# 2   19  MOWRY ST             Providence
# 3   19  MELISSA AVE          Providence
# 4   19  MELISSA AVE          Providence
# 5   19  MELISSA AVE          Providence
# 6   19  MINK RD              Providence           Rhode Island
# 7   19  SMITH ST             Providence
# 8   18  BENEDICT ST          Providence
# 9   18  CROSS ST             Providence
# 10  19  SILVER LAKE AVE      Providence
# 11  19  SILVER LAKE AVE      Providence
# 12  18  HANOVER ST           Providence
# 13  19  SILVER LAKE AVE      Providence
# 14  19  ROSEDALE AVE         PROVIDENCE
# 15  19  ROSEDALE ST          Providence
# 16  19  DOUGLAS AVE          Providence           Rhode Island
# 17  19  E MAIN ST            W BROOKFIELD ST
# 18  19  N.P.A
# 19  19  N.P.A
# 20  18  BRIDGHAM ST          Providence
# 21  18  BRIDGHAM ST          Providence
# 22  19  PUBLIC ST            Providence
# 23  18  LYNCH STREET         PROVIDENCE           Rhode Island
# 24  19  GALLATIN ST          Providence
# 25  19  HENDRICK ST          Providence
# 26  18  MANTON AVE           Providence
# 27  18  MANTON AVE           Providence
# 28  19
# 29  19  CHALKSTONE AVE       Providence
# 30  19  PUBLIC ST            Providence
# ⋮   ⋮   ⋮                    ⋮                    ⋮
# 565 19  S MAIN ST            SOUTH  ATTELBORO     NULL
# 566 18  HARTFORD AVE         Providence           NULL
# 567 19  ORMS ST              Providence           NULL
# 568 19  ORMS ST              Providence           NULL
# 569 19  ORMS ST              Providence           NULL
# 570 19  ORMS ST              Providence           NULL
# 571 19  CHERIF ST            NULL                 NULL
# 572 19  CHERIF ST            NULL                 NULL
# 573 19  PUBLIC ST            Providence           NULL
# 574 19  RANDI DRIVE          MADISON              NULL
# 575 18  No Permanent Address NULL                 NULL
# 576 19  PLAIN ST             Brockton             NULL
# 577 19  FARMERS CIR          Dartmouth            NULL
# 578 19  PHILLIPS ST          Fairhaven            NULL
# 579 19  NOBEL RD.            Dedham               NULL
# 580 18  SALMON ST            Providence           NULL
# 581 19  MARTENSEN ST         Quincy               NULL
# 582 19  BIRCH AVE            Westfield            NULL
# 583 19  OAKRIDGE DRIVE       Plainville           NULL
# 584 19  PATRICK RD           Westport             NULL
# 585 18  EAST OAKLAND AVE     East Haddon Township NULL
# 586 19  BRINKLEY ST          Providence           NULL
# 587 19  FELIX ST             Providence           NULL
# 588 18  CUNNINGHAM SQ        Providence           NULL
# 589 18  PARKIS AVE           Providence           NULL
# 590 18  PARKIS AVE           Providence           NULL
# 591 18  PARKIS AVE           Providence           NULL
# 592 18  PARKIS AVE           Providence           NULL
# 593 19  BLANCHAARD AVE       WARWICK              NULL
# 594 19  CHALKSTONE AVE       Providence           NULL
#     statute_type             statute_code
# 1   RI Statute Violation     31-27-4
# 2   RI Statute Violation     31-11-18
# 3   RI Statute Violation     12-7-10
# 4   RI Statute Violation     11-45-1
# 5   RI Statute Violation     31-11-18
# 6   RI Statute Violation     31-27-4
# 7
# 8   RI Statute Violation     11-37-2
# 9   RI Statute Violation     11-17-1
# 10
# 11
# 12  RI Statute Violation     31-9-1
# 13
# 14  Warrant\\Capias          BWARRANT-SC
# 15  Warrant\\Capias          BWARRANT-6D
# 16
# 17  Municipal Code Violation Sec. 16-3.E
# 18  RI Statute Violation     11-8-4
# 19  RI Statute Violation     11-1-6
# 20  RI Statute Violation     11-8-4
# 21  RI Statute Violation     11-1-6
# 22  RI Statute Violation     31-11-18
# 23  RI Statute Violation     11-47-42
# 24  RI Statute Violation     11-41-1
# 25
# 26  RI Statute Violation     11-47-8-A
# 27  RI Statute Violation     11-47-5.2
# 28  Municipal Code Violation Sec. 23-32.
# 29  RI Statute Violation     11-47-8-A
# 30
# ⋮   ⋮                        ⋮
# 565 NULL                     NULL
# 566 NULL                     NULL
# 567 RI Statute Violation     11-5-2
# 568 RI Statute Violation     11-47-8-A
# 569 RI Statute Violation     11-47-3.2-B
# 570 RI Statute Violation     11-1-6
# 571 RI Statute Violation     12-7-10
# 572 Municipal Code Violation Sec. 16-3.A
# 573 RI Statute Violation     11-41-1
# 574 NULL                     NULL
# 575 NULL                     NULL
# 576 NULL                     NULL
# 577 RI Statute Violation     3-8-10
# 578 RI Statute Violation     3-8-10
# 579 RI Statute Violation     3-8-10
# 580 NULL                     NULL
# 581 RI Statute Violation     3-8-10
# 582 NULL                     NULL
# 583 RI Statute Violation     3-8-10
# 584 NULL                     NULL
# 585 RI Statute Violation     3-8-10
# 586 RI Statute Violation     11-45-1
# 587 RI Statute Violation     11-39-1
# 588 RI Statute Violation     3-8-10
# 589 RI Statute Violation     11-5-2
# 590 RI Statute Violation     11-47-8-A
# 591 RI Statute Violation     11-47-3.2-B
# 592 RI Statute Violation     11-1-6
# 593 NULL                     NULL
# 594 RI Statute Violation     31-11-18
#     statute_desc
# 1   Reckless Driving, Drag Racing - Attempting to Elude
# 2   Driving after Denial, Suspension or Revocation of License
# 3   RESISTING LEGAL OR ILLEGAL ARREST
# 4   DISORDERLY CONDUCT
# 5   Driving after Denial, Suspension or Revocation of License
# 6   Reckless Driving, Drag Racing - Attempting to Elude
# 7
# 8   SEXUAL ASSAULT -1ST DEGREE - FRC RAPE
# 9   FORGERY AND COUNTERFEITING IN GENERAL
# 10
# 11
# 12  Driving Without Consent of Owner
# 13
# 14  BENCH WARRANT ISSUED FROM SUPERIOR COURT
# 15  BENCH WARRANT ISSUED FROM 6TH DISTRICT COURT
# 16
# 17  Disorderly Conduct E - Assemble to cause a fight
# 18  B&E BUS.PLACE PUBLIC BLDG  OR SHIP W/FEL. INTENT
# 19  CONSPIRACY - ALL OTH OFFENSE
# 20  B&E BUS.PLACE PUBLIC BLDG  OR SHIP W/FEL. INTENT
# 21  CONSPIRACY - ALL OTH OFFENSE
# 22  Driving after Denial, Suspension or Revocation of License
# 23  WEAPONS OTHER THAN FIREARMS PROHIBITED
# 24  LARCENY/O $1500 - AUTO THEFT
# 25
# 26  LICENSE OR PERMIT REQUIRED FOR CARRYING PISTOL
# 27  POSSESSION OF A STOLEN FIREARM
# 28   Possession ,of alcoholic beverages on any public street, sidewalk, licensed parking lot, way or grounds owned by city.
# 29  LICENSE OR PERMIT REQUIRED FOR CARRYING PISTOL
# 30
# ⋮   ⋮
# 565 NULL
# 566 NULL
# 567 FELONY ASSAULT/ DANG. WEAPON OR SUBSTANCE
# 568 LICENSE OR PERMIT REQUIRED FOR CARRYING PISTOL
# 569 DISCHARGE OF FA WHILE COMMITTING CRIME OF VIOLENCE
# 570 CONSPIRACY - ALL OTH OFFENSE
# 571 RESISTING LEGAL OR ILLEGAL ARREST
# 572 Disorderly and indecent conduct A - Theatening
# 573 LARCENY/U $1500 - ALL OTH LARCENY
# 574 NULL
# 575 NULL
# 576 NULL
# 577 POSSESSION OF BEVERAGE-UNDERAGE PERSONS
# 578 POSSESSION OF BEVERAGE-UNDERAGE PERSONS
# 579 POSSESSION OF BEVERAGE-UNDERAGE PERSONS
# 580 NULL
# 581 POSSESSION OF BEVERAGE-UNDERAGE PERSONS
# 582 NULL
# 583 POSSESSION OF BEVERAGE-UNDERAGE PERSONS
# 584 NULL
# 585 POSSESSION OF BEVERAGE-UNDERAGE PERSONS
# 586 DISORDERLY CONDUCT
# 587 ROBBERY-1ST DEGREE
# 588 POSSESSION OF BEVERAGE-UNDERAGE PERSONS
# 589 FELONY ASSAULT/ DANG. WEAPON OR SUBSTANCE
# 590 LICENSE OR PERMIT REQUIRED FOR CARRYING PISTOL
# 591 DISCHARGE OF FA WHILE COMMITTING CRIME OF VIOLENCE
# 592 CONSPIRACY - ALL OTH OFFENSE
# 593 NULL
# 594 Driving after Denial, Suspension or Revocation of License
#     counts case_number
# 1    1     2019-00083996
# 2    1     2019-00083996
# 3    1     2019-00083170
# 4    1     2019-00083170
# 5    1     2019-00083170
# 6    1     2019-00078616
# 7   NA     2019-00082826
# 8    1     2019-00081517
# 9    1     2019-00080859
# 10  NA     2019-00076472
# 11  NA     2019-00077312
# 12   1     2019-00080555
# 13  NA     2019-00080526
# 14   1     2019-00080173
# 15   1     2019-00080173
# 16  NA     2019-00078358
# 17   1     2019-00078143
# 18   1     2019-00078114
# 19   1     2019-00078114
# 20   1     2019-00078114
# 21   1     2019-00078114
# 22   1     2019-00077051
# 23   1     2019-00076968
# 24   1     2019-00074588
# 25  NA     2019-00074559
# 26   1     2019-00074254
# 27   1     2019-00074254
# 28   1     2019-00074254
# 29   1     2019-00073770
# 30  NA     2019-00073335
# ⋮   ⋮      ⋮
# 565 NA     2021-00062264
# 566 NA     2021-00065323
# 567  1     2021-00062608
# 568  1     2021-00062608
# 569  1     2021-00062608
# 570  1     2021-00062608
# 571  1     2021-00067120
# 572  1     2021-00067120
# 573  1     2021-00067962
# 574 NA     2021-00069663
# 575 NA     2021-00070018
# 576 NA     2021-00068997
# 577  1     2021-00068967
# 578  1     2021-00068967
# 579  1     2021-00068967
# 580 NA     2021-00068531
# 581  1     2021-00071209
# 582 NA     2021-00071870
# 583  1     2021-00071888
# 584 NA     2021-00071907
# 585  1     2021-00071899
# 586  1     2021-00072693
# 587  1     2020-00074435
# 588  1     2021-00074005
# 589  1     2021-00062608
# 590  1     2021-00062608
# 591  1     2021-00062608
# 592  1     2021-00062608
# 593 NA     2021-00075126
# 594  1     2021-00077115
#     arresting_officers
# 1    SCampbell, RMalloy
# 2    SCampbell, RMalloy
# 3    ITavarez, IYousif, CBrown, EDelgado
# 4    ITavarez, IYousif, CBrown, EDelgado
# 5    ITavarez, IYousif, CBrown, EDelgado
# 6    JGagnon, RMalloy
# 7    RPapa, MCamardo
# 8    RMendez, JNajarian
# 9    JBenros, JStanzione, NOC Officer, ACalle, EDelgado, JManown
# 10
# 11
# 12   JCascione, WSherrill, DForte
# 13
# 14   MRudolph, LTaveras, ITorres, YCaba
# 15   MRudolph, LTaveras, ITorres, YCaba
# 16
# 17   JAndrade, PSalmons
# 18   BMuldoon, JCascione, TCalandra, ITorres, LVadney, GVargas, DForte
# 19   BMuldoon, JCascione, TCalandra, ITorres, LVadney, GVargas, DForte
# 20   LVadney, GVargas
# 21   LVadney, GVargas
# 22   PSalmons, WPognon
# 23   MPlace, NO'Malley
# 24   MMena-Torres, ASantos
# 25   ITavarez, FTavares
# 26   RFoley, BMurphy, JSmith
# 27   RFoley, BMurphy, JSmith
# 28   RFoley, BMurphy, JSmith
# 29   NOC Officer
# 30   MJennette
# ⋮   ⋮
# 565 Tesseris, Peter/ Silbert, Zachary
# 566 Sherrill, William/ Antoniou, Jan-Delle
# 567 Stanzione, Jared
# 568 Stanzione, Jared
# 569 Stanzione, Jared
# 570 Stanzione, Jared
# 571 Bento, John
# 572 Bento, John
# 573 Cotugno, Jason/ Manfredi, Nicholas
# 574 Sollitto, Vincent/ Savard, Thomas/ Ballinger, Robert
# 575 Antoniou, Jan-Delle
# 576 Hourahan, Patrick/ Sanchez, Damaris/ Sandorse, Matthew/ Ventura, Hansel
# 577 Shields, Derek/ Doucette, Jeremy/ Castro, Ludwig
# 578 Shields, Derek/ Doucette, Jeremy/ Castro, Ludwig
# 579 Shields, Derek/ Doucette, Jeremy/ Castro, Ludwig
# 580 Dyer, Brian/ Cascione, Joshua
# 581 Shields, Derek/ Doucette, Jeremy/ Castro, Ludwig
# 582 Marmas, Shaun/ Criner, Raymond/ Savard, Thomas/ Ballinger, Robert
# 583 Northup, Harrison
# 584 Marmas, Shaun/ Savard, Thomas/ Ballinger, Robert
# 585 Marmas, Shaun/ Northup, Harrison/ Criner, Raymond/ Savard, Thomas/ Ballinger, Robert
# 586 Pichs, Leonel
# 587 Sandorse, Matthew
# 588 Shields, Derek/ Castro, Ludwig
# 589 Stanzione, Jared
# 590 Stanzione, Jared
# 591 Stanzione, Jared
# 592 Stanzione, Jared
# 593 Pirolli, Jonathyn
# 594 Vingi, Cory
#     id
# 1   pvd900460037611487829
# 2   pvd900460037611487829
# 3   pvd5047836359365815220
# 4   pvd5047836359365815220
# 5   pvd5047836359365815220
# 6   pvd1076862233562848683
# 7   pvd12708633210022966227
# 8   pvd9938776757456909177
# 9   pvd17954097329236445270
# 10  pvd14598067460260984586
# 11  pvd14598067460260984586
# 12  pvd546562814918541603
# 13  pvd14598067460260984586
# 14  pvd9323950046473646552
# 15  pvd14813725095613585348
# 16  pvd1938991043458143228
# 17  pvd14040038903267330143
# 18  pvd11009793417040053856
# 19  pvd11009793417040053856
# 20  pvd6172294185293902322
# 21  pvd6172294185293902322
# 22  pvd5047836359365815220
# 23  pvd4893497626930297345
# 24  pvd1009900097149203760
# 25  pvd15086432552233156035
# 26  pvd6964622917035835812
# 27  pvd6964622917035835812
# 28  pvd2108948915874802496
# 29  pvd16220229943014753234
# 30  pvd12052530703955757820
# ⋮   ⋮
# 565 pvd13645407761131183091
# 566 pvd4660823648581770501
# 567 pvd3722809446029683335
# 568 pvd3722809446029683335
# 569 pvd3722809446029683335
# 570 pvd3722809446029683335
# 571 pvd9953657741786253443
# 572 pvd9953657741786253443
# 573 pvd17679973011144850980
# 574 pvd4382683218266153709
# 575 pvd14980380711728044719
# 576 pvd1191531330760537537
# 577 pvd11693418457228103722
# 578 pvd13266562089114061443
# 579 pvd3763110185922116521
# 580 pvd8193591812103030255
# 581 pvd208990088333228546
# 582 pvd16050843560429695032
# 583 pvd11357386846153682159
# 584 pvd1192807488558811780
# 585 pvd14564314486622194135
# 586 pvd9952489541440734221
# 587 pvd13299152107167679603
# 588 pvd5195074301745935018
# 589 pvd13474061105520308850
# 590 pvd13474061105520308850
# 591 pvd13474061105520308850
# 592 pvd13474061105520308850
# 593 pvd3396272140312660794
# 594 pvd6105586092259284839

# %% [markdown]
# ### 7.2.1 Using `filter()` with Logical OR
#
#   - Recall the `||` operator is the logical OR
#   - The `|` operator performs the same role, but elementwise for columns (or vectors)

# %%
young_old_male <- arrests_df %>%
    filter(
        gender == "Male",
        age < 25 | age > 65  
    )
   
young_old_male
# Out:
#      arrest_date           year month gender race                   ethnicity
# 1    2019-08-23T21:38:00.0 2019 8     Male   White                  Hispanic
# 2    2019-08-23T19:50:00.0 2019 8     Male   White                  Hispanic
# 3    2019-08-23T19:50:00.0 2019 8     Male   White                  Hispanic
# 4    2019-08-23T18:26:00.0 2019 8     Male   White                  Hispanic
# 5    2019-08-23T18:26:00.0 2019 8     Male   White                  Hispanic
# 6    2019-08-23T14:42:00.0 2019 8     Male   White                  Hispanic
# 7    2019-08-23T00:57:00.0 2019 8     Male   White
# 8    2019-08-22T12:05:00.0 2019 8     Male   White                  Hispanic
# 9    2019-08-22T01:38:00.0 2019 8     Male   Black                  Hispanic
# 10   2019-08-21T18:03:00.0 2019 8     Male   Unknown                Hispanic
# 11   2019-08-21T16:00:00.0 2019 8     Male   White                  Hispanic
# 12   2019-08-21T13:09:00.0 2019 8     Male   White                  Hispanic
# 13   2019-08-21T13:09:00.0 2019 8     Male   White                  Hispanic
# 14   2019-08-21T13:09:00.0 2019 8     Male   White                  Hispanic
# 15   2019-08-20T20:23:00.0 2019 8     Male   Black                  NonHispanic
# 16   2019-08-20T02:00:00.0 2019 8     Male   White                  Hispanic
# 17   2019-08-20T00:00:00.0 2019 8     Male   Black                  NonHispanic
# 18   2019-08-19T14:25:00.0 2019 8     Male   White                  Hispanic
# 19   2019-08-19T12:27:00.0 2019 8     Male   White                  Hispanic
# 20   2019-08-19T11:01:00.0 2019 8     Male   Black                  Hispanic
# 21   2019-08-19T11:01:00.0 2019 8     Male   Black                  Hispanic
# 22   2019-08-18T03:21:00.0 2019 8     Male   Black                  NonHispanic
# 23   2019-08-18T02:56:00.0 2019 8     Male   White                  NonHispanic
# 24   2019-08-17T11:53:00.0 2019 8     Male   Black                  Hispanic
# 25   2019-08-17T00:00:00.0 2019 8     Male   White                  Hispanic
# 26   2019-08-16T16:56:00.0 2019 8     Male   White                  Hispanic
# 27   2019-08-16T00:43:00.0 2019 8     Male   Black                  Hispanic
# 28   2019-08-16T00:00:00.0 2019 8     Male   Black                  NonHispanic
# 29   2019-08-16T00:00:00.0 2019 8     Male   Black                  NonHispanic
# 30   2019-08-15T18:12:00.0 2019 8     Male   Black                  NonHispanic
# ⋮    ⋮                     ⋮    ⋮     ⋮      ⋮                      ⋮
# 2650 2021-09-18T17:23:00.0 2021  9    Male   White                  Hispanic
# 2651 2021-09-18T19:25:00.0 2021  9    Male   White                  NonHispanic
# 2652 2021-09-18T19:25:00.0 2021  9    Male   White                  NonHispanic
# 2653 2021-09-18T19:25:00.0 2021  9    Male   White                  NonHispanic
# 2654 2021-09-20T17:53:00.0 2021  9    Male   Black                  Hispanic
# 2655 2021-09-20T21:30:00.0 2021  9    Male   White                  Hispanic
# 2656 2021-09-09T00:00:00.0 2021  9    Male   White                  Unknown
# 2657 2021-09-21T11:30:00.0 2021  9    Male   Black                  NonHispanic
# 2658 2021-09-21T11:30:00.0 2021  9    Male   Black                  NonHispanic
# 2659 2021-09-21T11:30:00.0 2021  9    Male   Black                  NonHispanic
# 2660 2021-09-21T11:30:00.0 2021  9    Male   Black                  NonHispanic
# 2661 2021-09-21T18:04:00.0 2021  9    Male   Black                  Hispanic
# 2662 2021-09-22T14:40:00.0 2021  9    Male   White                  Hispanic
# 2663 2021-09-22T16:17:00.0 2021  9    Male   Black                  NonHispanic
# 2664 2021-09-23T00:00:00.0 2021  9    Male   Asian/Pacific Islander NULL
# 2665 2021-09-24T05:20:00.0 2021  9    Male   Black                  Hispanic
# 2666 2021-09-24T20:00:00.0 2021  9    Male   White                  Hispanic
# 2667 2021-09-25T12:20:00.0 2021  9    Male   White                  NonHispanic
# 2668 2021-09-25T12:20:00.0 2021  9    Male   White                  NonHispanic
# 2669 2021-09-26T04:54:00.0 2021  9    Male   Black                  NonHispanic
# 2670 2021-09-26T19:20:00.0 2021  9    Male   White                  Hispanic
# 2671 2021-09-20T21:30:00.0 2021  9    Male   White                  Hispanic
# 2672 2021-09-24T05:20:00.0 2021  9    Male   Black                  Hispanic
# 2673 2021-09-27T16:08:00.0 2021  9    Male   White                  Hispanic
# 2674 2021-09-29T06:06:00.0 2021  9    Male   Black                  Hispanic
# 2675 2021-09-28T22:33:00.0 2021  9    Male   Black                  NonHispanic
# 2676 2021-09-28T11:00:00.0 2021  9    Male   Black                  NonHispanic
# 2677 2021-09-29T07:05:00.0 2021  9    Male   White                  Hispanic
# 2678 2021-09-29T00:00:00.0 2021  9    Male   Black                  NonHispanic
# 2679 2021-10-01T00:05:00.0 2021 10    Male   Black                  Hispanic
#      year_of_birth age from_address         from_city        from_state
# 1    1996          22  DOUGLAS              Providence
# 2    2000          19  MOWRY ST             Providence
# 3    2000          19  MOWRY ST             Providence
# 4    1996          23  CUMERFORD ST         Providence
# 5    1996          23  CUMERFORD ST         Providence
# 6    1998          20  LAURA ST             Providence
# 7    1998          21  AUSTIN ST            newbrdford
# 8    1999          20  ROCKINGHAM ST        Providence       Rhode Island
# 9    1998          21  HOLLIS ST            Providence
# 10   1998          21  CUMERFORD ST         Providence
# 11   1995          23  MINTO ST             Providence
# 12   1999          19  MELISSA AVE          Providence
# 13   1999          19  MELISSA AVE          Providence
# 14   1999          19  MELISSA AVE          Providence
# 15   1999          20  VIOLET ST            Providence
# 16   1999          19  MINK RD              Providence       Rhode Island
# 17   2000          19  SMITH ST             Providence
# 18   1997          21  PARNELL ST           Providence
# 19   1998          20  WASHINGTON ST        Providence
# 20   1996          23  LEE RD               e. providence
# 21   1996          23  LEE RD               e. providence
# 22   1999          20  WENDELL ST           Providence
# 23   1998          21  HOWE STREET          MANCHESTER
# 24   1999          20  HOMESTEAD AVE        Providence
# 25   2001          18  BENEDICT ST          Providence
# 26   1995          23  WINTHROP AVE         Providence
# 27   1998          20  LINTON ST            Pawtucket
# 28   1996          22  No Permanent Address Providence
# 29   1996          22  No Permanent Address Providence
# 30   2000          18  CROSS ST             Providence
# ⋮    ⋮             ⋮   ⋮                    ⋮                ⋮
# 2650 1998          23  MANTON AVE           Providence       Rhode Island
# 2651 2001          20  CUNNINGHAM SQ        Providence       NULL
# 2652 2001          20  WYNDEMARK CT.        Cheshire         NULL
# 2653 2002          18  CUNNINGHAM SQ        Providence       NULL
# 2654 2001          20  POST RD              Warwick          NULL
# 2655 1998          22  ALEXANDER ST         Providence       NULL
# 2656 1998          23  BROAD ST             Providence       NULL
# 2657 2003          18  PARKIS AVE           Providence       NULL
# 2658 2003          18  PARKIS AVE           Providence       NULL
# 2659 2003          18  PARKIS AVE           Providence       NULL
# 2660 2003          18  PARKIS AVE           Providence       NULL
# 2661 1999          22  PETER ST             Providence       NULL
# 2662 1952          68  OSBORN ST            Providence       Rhode Island
# 2663 2001          19  BLANCHAARD AVE       WARWICK          NULL
# 2664 1944          77  DOUGLAS AVENUE 4101  North Providence NULL
# 2665 1998          23  NULL                 NULL             NULL
# 2666 1998          23  MADISON ST           Providence       NULL
# 2667 2001          20  GODDARD ST           Providence       NULL
# 2668 2001          20  GODDARD ST           Providence       NULL
# 2669 1998          23  MCTEER CT            WEST WARWICK     NULL
# 2670 1999          22  No Permanent Address NULL             NULL
# 2671 1998          22  ALEXANDER ST         Providence       NULL
# 2672 1998          23  NULL                 NULL             NULL
# 2673 1998          23  METCALF ST           Providence       Rhode Island
# 2674 2000          20  FORD ST              Providence       NULL
# 2675 2002          19  CHALKSTONE AVE       Providence       NULL
# 2676 1954          66  PUBLIC ST            Providence       NULL
# 2677 2001          20  JULIAN ST            Providence       NULL
# 2678 1954          67  RUSSO ST             Providence       NULL
# 2679 1952          68  PHEBE ST             Providence       Rhode Island
#      statute_type             statute_code
# 1    RI Statute Violation     11-44-1
# 2    RI Statute Violation     31-27-4
# 3    RI Statute Violation     31-11-18
# 4    RI Statute Violation     12-7-10
# 5    RI Statute Violation     11-32-1
# 6    RI Statute Violation     11-44-1
# 7    RI Statute Violation     11-5-3
# 8    RI Statute Violation     31-11-18
# 9    RI Statute Violation     11-47-5.2
# 10   RI Statute Violation     31-11-18
# 11   RI Statute Violation     31-26-2
# 12   RI Statute Violation     12-7-10
# 13   RI Statute Violation     11-45-1
# 14   RI Statute Violation     31-11-18
# 15
# 16   RI Statute Violation     31-27-4
# 17
# 18   RI Statute Violation     11-5-3
# 19
# 20   Warrant\\Capias          BWARRANT-6D
# 21   RI Statute Violation     31-11-18
# 22
# 23   RI Statute Violation     11-45-1
# 24   RI Statute Violation     31-11-18
# 25   RI Statute Violation     11-37-2
# 26   RI Statute Violation     21-28-4.01-A2A
# 27   RI Statute Violation     21-28-4.01-C1A
# 28   RI Statute Violation     11-41-24
# 29   RI Statute Violation     11-41-20
# 30   RI Statute Violation     11-17-1
# ⋮    ⋮                        ⋮
# 2650 RI Statute Violation     31-11-18
# 2651 RI Statute Violation     3-8-10
# 2652 RI Statute Violation     3-8-10
# 2653 RI Statute Violation     3-8-10
# 2654 NULL                     NULL
# 2655 NULL                     NULL
# 2656 NULL                     NULL
# 2657 RI Statute Violation     11-5-2
# 2658 RI Statute Violation     11-47-8-A
# 2659 RI Statute Violation     11-47-3.2-B
# 2660 RI Statute Violation     11-1-6
# 2661 RI Statute Violation     11-5-3
# 2662 NULL                     NULL
# 2663 NULL                     NULL
# 2664 NULL                     NULL
# 2665 NULL                     NULL
# 2666 RI Statute Violation     11-45-1
# 2667 RI Statute Violation     11-5-3
# 2668 Municipal Code Violation Sec. 16-3.C
# 2669 RI Statute Violation     11-47-8-A
# 2670 RI Statute Violation     11-41-20
# 2671 RI Statute Violation     12-29-4
# 2672 RI Statute Violation     11-5-3
# 2673 NULL                     NULL
# 2674 NULL                     NULL
# 2675 RI Statute Violation     31-11-18
# 2676 RI Statute Violation     11-37.1-3
# 2677 RI Statute Violation     11-8-2
# 2678 RI Statute Violation     11-5-3
# 2679 NULL                     NULL
#      statute_desc                                                       counts
# 1    DOMESTIC-VANDALISM/MALICIOUS INJURY TO PROP                         1
# 2    Reckless Driving, Drag Racing - Attempting to Elude                 1
# 3    Driving after Denial, Suspension or Revocation of License           1
# 4    RESISTING LEGAL OR ILLEGAL ARREST                                   1
# 5    OBSTRUCTING OFFICER IN EXECUTION OF DUTY                            1
# 6    DOMESTIC-VANDALISM/MALICIOUS INJURY TO PROP                         1
# 7    SIMPLE ASSAULT OR BATTERY                                           1
# 8    Driving after Denial, Suspension or Revocation of License           1
# 9    POSSESSION OF A STOLEN FIREARM                                      1
# 10   Driving after Denial, Suspension or Revocation of License           1
# 11   Duty to Stop in Accidents Resulting in Damage to Attended Vehicles  1
# 12   RESISTING LEGAL OR ILLEGAL ARREST                                   1
# 13   DISORDERLY CONDUCT                                                  1
# 14   Driving after Denial, Suspension or Revocation of License           1
# 15                                                                      NA
# 16   Reckless Driving, Drag Racing - Attempting to Elude                 1
# 17                                                                      NA
# 18   SIMPLE ASSAULT OR BATTERY                                           1
# 19                                                                      NA
# 20   BENCH WARRANT ISSUED FROM 6TH DISTRICT COURT                        1
# 21   Driving after Denial, Suspension or Revocation of License           1
# 22                                                                      NA
# 23   DISORDERLY CONDUCT                                                  1
# 24   Driving after Denial, Suspension or Revocation of License           1
# 25   SEXUAL ASSAULT -1ST DEGREE - FRC RAPE                               1
# 26   MANUFAC/POSS/DELIVER SCH 1/II                                       1
# 27   POSSESSION OF SCHEDULE I II III                                     1
# 28   HABITUAL OFFENDER-SHOPLIFTING                                       1
# 29   SHOPLIFTING-FELONY - SHOPLIFTING                                    1
# 30   FORGERY AND COUNTERFEITING IN GENERAL                               1
# ⋮    ⋮                                                                  ⋮
# 2650 Driving after Denial, Suspension or Revocation of License           1
# 2651 POSSESSION OF BEVERAGE-UNDERAGE PERSONS                             1
# 2652 POSSESSION OF BEVERAGE-UNDERAGE PERSONS                             1
# 2653 POSSESSION OF BEVERAGE-UNDERAGE PERSONS                             1
# 2654 NULL                                                               NA
# 2655 NULL                                                               NA
# 2656 NULL                                                               NA
# 2657 FELONY ASSAULT/ DANG. WEAPON OR SUBSTANCE                           1
# 2658 LICENSE OR PERMIT REQUIRED FOR CARRYING PISTOL                      1
# 2659 DISCHARGE OF FA WHILE COMMITTING CRIME OF VIOLENCE                  1
# 2660 CONSPIRACY - ALL OTH OFFENSE                                        1
# 2661 DOMESTIC-SIMPLE ASSAULT/BATTERY                                     1
# 2662 NULL                                                               NA
# 2663 NULL                                                               NA
# 2664 NULL                                                               NA
# 2665 NULL                                                               NA
# 2666 DISORDERLY CONDUCT                                                  1
# 2667 DOMESTIC-SIMPLE ASSAULT/BATTERY                                     1
# 2668 Disorderly Conduct C - Fighting Words                               1
# 2669 LICENSE OR PERMIT REQUIRED FOR CARRYING PISTOL                      1
# 2670 SHOPLIFTING-MISD - SHOPLIFTING                                      1
# 2671 VIOLATION -NO CONTACT ORDER                                         1
# 2672 DOMESTIC-SIMPLE ASSAULT/BATTERY                                     1
# 2673 NULL                                                               NA
# 2674 NULL                                                               NA
# 2675 Driving after Denial, Suspension or Revocation of License           1
# 2676 SEXUAL OFFENDER REGISTRATION REQUIRED                               1
# 2677 B&E DWELLING HOUSE W/O CONSENT                                      1
# 2678 SIMPLE ASSAULT OR BATTERY                                           1
# 2679 NULL                                                               NA
#      case_number
# 1    2019-00084031
# 2    2019-00083996
# 3    2019-00083996
# 4    2019-00083963
# 5    2019-00083963
# 6    2019-00083892
# 7    2019-00083725
# 8    2019-00083486
# 9    2019-00083396
# 10   2019-00083274
# 11   2019-00083178
# 12   2019-00083170
# 13   2019-00083170
# 14   2019-00083170
# 15   2019-00082937
# 16   2019-00078616
# 17   2019-00082826
# 18   2019-00082422
# 19   2019-00082384
# 20   2019-00082356
# 21   2019-00082356
# 22   2019-00081915
# 23   2019-00081919
# 24   2019-00081587
# 25   2019-00081517
# 26   2019-00081240
# 27   2019-00081015
# 28   2019-00081319
# 29   2019-00081319
# 30   2019-00080859
# ⋮    ⋮
# 2650 2021-00073933
# 2651 2021-00074005
# 2652 2021-00074005
# 2653 2021-00074005
# 2654 2021-00074597
# 2655 2021-00074648
# 2656 2021-00071029
# 2657 2021-00062608
# 2658 2021-00062608
# 2659 2021-00062608
# 2660 2021-00062608
# 2661 2021-00074894
# 2662 2021-00075094
# 2663 2021-00075126
# 2664 2021-00075345
# 2665 2021-00075561
# 2666 2021-00075783
# 2667 2021-00075997
# 2668 2021-00075997
# 2669 2021-00076278
# 2670 2021-00076436
# 2671 2021-00074648
# 2672 2021-00075561
# 2673 2021-00076724
# 2674 2021-00077156
# 2675 2021-00077115
# 2676 2020-00004402
# 2677 2021-00077161
# 2678 2021-00077379
# 2679 2021-00077654
#      arresting_officers
# 1     RCarlin, SKennedy
# 2     SCampbell, RMalloy
# 3     SCampbell, RMalloy
# 4     JHanley
# 5     JHanley
# 6     JCotugno, ALevesque, JButen, JJohnson
# 7     PSalmons
# 8     JBenros, MClary
# 9     RFedo, KRosado, ALugo
# 10    JMadeira
# 11    JLugo
# 12    ITavarez, IYousif, CBrown, EDelgado
# 13    ITavarez, IYousif, CBrown, EDelgado
# 14    ITavarez, IYousif, CBrown, EDelgado
# 15    EBreault, LMarroquin, KRichards, TSavard, DDiaz
# 16    JGagnon, RMalloy
# 17    RPapa, MCamardo
# 18    JRodrigues, DForte
# 19    JStanzione, DHernandez
# 20    LFernandez, CBenoit, CClift
# 21    LFernandez, CBenoit, CClift
# 22    KRosado, FTavares
# 23    SKennedy
# 24    JBenros, JCotugno
# 25    RMendez, JNajarian
# 26    NOC Officer
# 27    BMcKenna
# 28    RAbenante, RGaudiana
# 29    RAbenante, RGaudiana
# 30    JBenros, JStanzione, NOC Officer, ACalle, EDelgado, JManown
# ⋮    ⋮
# 2650 Breault, Erik
# 2651 Shields, Derek/ Castro, Ludwig
# 2652 Shields, Derek/ Castro, Ludwig
# 2653 Shields, Derek/ Castro, Ludwig
# 2654 Rousseau, Matthew
# 2655 Moore, Anthony
# 2656 Diaz, Alex
# 2657 Stanzione, Jared
# 2658 Stanzione, Jared
# 2659 Stanzione, Jared
# 2660 Stanzione, Jared
# 2661 Mancini, Mark/ Breault, Erik/ Calandra, Tyler/ Savard, Thomas
# 2662 Savard, Thomas
# 2663 Pirolli, Jonathyn
# 2664 Lopes, Joseph
# 2665 Santos, Alexandre/ Subramaniam, Ajay
# 2666 Potter, Patrick
# 2667 Rodrigues, Juan/ Tavarez, Ivan
# 2668 Rodrigues, Juan/ Tavarez, Ivan
# 2669 Calle, Andrew/ Prete, Louis/ Subramaniam, Ajay/ Ventura, Hansel
# 2670 Im, Southavout/ Anderson, Darrin
# 2671 Moore, Anthony
# 2672 Santos, Alexandre/ Subramaniam, Ajay
# 2673 Hines, Christopher
# 2674 Addai, Mabel/ Prete, Louis/ Subramaniam, Ajay
# 2675 Vingi, Cory
# 2676 Stanzione, Jared
# 2677 Dalton, Jason/ Valletta, Giana
# 2678 Criner, Raymond
# 2679 Silva, Eric
#      id
# 1    pvd15614289459563584867
# 2    pvd900460037611487829
# 3    pvd900460037611487829
# 4    pvd1675234703933765967
# 5    pvd1675234703933765967
# 6    pvd17953747948212880432
# 7    pvd3024232238010666153
# 8    pvd8008374038901187780
# 9    pvd6386847572324309475
# 10   pvd14028206778351997883
# 11   pvd15484437773558878491
# 12   pvd5047836359365815220
# 13   pvd5047836359365815220
# 14   pvd5047836359365815220
# 15   pvd11307430541739268546
# 16   pvd1076862233562848683
# 17   pvd12708633210022966227
# 18   pvd1659949234730464312
# 19   pvd14980793063563348172
# 20   pvd8740720143141443756
# 21   pvd8740720143141443756
# 22   pvd11381887219559117536
# 23   pvd11675033727467519694
# 24   pvd16591707559944991069
# 25   pvd9938776757456909177
# 26   pvd17516830937488095084
# 27   pvd9281906170407203949
# 28   pvd10959757297184382072
# 29   pvd10959757297184382072
# 30   pvd17954097329236445270
# ⋮    ⋮
# 2650 pvd15521911881392239140
# 2651 pvd6205748667965642541
# 2652 pvd16397125318715867803
# 2653 pvd5195074301745935018
# 2654 pvd16301983516170635166
# 2655 pvd3638004533788767077
# 2656 pvd16722556137071805905
# 2657 pvd13474061105520308850
# 2658 pvd13474061105520308850
# 2659 pvd13474061105520308850
# 2660 pvd13474061105520308850
# 2661 pvd4576819876417022713
# 2662 pvd15228838999240996878
# 2663 pvd3396272140312660794
# 2664 pvd15274332284830779319
# 2665 pvd7703140614960407244
# 2666 pvd14393267306680258758
# 2667 pvd15281745511360817394
# 2668 pvd15281745511360817394
# 2669 pvd7899318447387645526
# 2670 pvd10454924037835051453
# 2671 pvd3638004533788767077
# 2672 pvd7703140614960407244
# 2673 pvd14295253119011323372
# 2674 pvd5794071766434905521
# 2675 pvd6105586092259284839
# 2676 pvd12048292079609555360
# 2677 pvd4887358463020255390
# 2678 pvd11372458517369102932
# 2679 pvd10501230489459422006

# %% [markdown]
# ### 7.2.2 Using `filter()` with Logical OR (cont.)

# %%
ptk_young_old_male <- arrests_df %>%
    filter(
        gender == "Male",
        age < 25 | age > 65 | from_city == "Pawtucket"
    )

ptk_young_old_male
# Out:
#      arrest_date           year month gender race                   ethnicity
# 1    2019-08-23T21:38:00.0 2019 8     Male   White                  Hispanic
# 2    2019-08-23T19:50:00.0 2019 8     Male   White                  Hispanic
# 3    2019-08-23T19:50:00.0 2019 8     Male   White                  Hispanic
# 4    2019-08-23T18:26:00.0 2019 8     Male   White                  Hispanic
# 5    2019-08-23T18:26:00.0 2019 8     Male   White                  Hispanic
# 6    2019-08-23T14:42:00.0 2019 8     Male   White                  Hispanic
# 7    2019-08-23T00:57:00.0 2019 8     Male   White
# 8    2019-08-22T12:05:00.0 2019 8     Male   White                  Hispanic
# 9    2019-08-22T01:38:00.0 2019 8     Male   Black                  Hispanic
# 10   2019-08-21T18:03:00.0 2019 8     Male   Unknown                Hispanic
# 11   2019-08-21T16:00:00.0 2019 8     Male   White                  Hispanic
# 12   2019-08-21T13:09:00.0 2019 8     Male   White                  Hispanic
# 13   2019-08-21T13:09:00.0 2019 8     Male   White                  Hispanic
# 14   2019-08-21T13:09:00.0 2019 8     Male   White                  Hispanic
# 15   2019-08-20T20:23:00.0 2019 8     Male   Black                  NonHispanic
# 16   2019-08-20T02:00:00.0 2019 8     Male   White                  Hispanic
# 17   2019-08-20T00:00:00.0 2019 8     Male   Black                  NonHispanic
# 18   2019-08-19T14:25:00.0 2019 8     Male   White                  Hispanic
# 19   2019-08-19T12:27:00.0 2019 8     Male   White                  Hispanic
# 20   2019-08-19T11:01:00.0 2019 8     Male   Black                  Hispanic
# 21   2019-08-19T11:01:00.0 2019 8     Male   Black                  Hispanic
# 22   2019-08-18T03:21:00.0 2019 8     Male   Black                  NonHispanic
# 23   2019-08-18T02:56:00.0 2019 8     Male   White                  NonHispanic
# 24   2019-08-17T21:36:00.0 2019 8     Male   White                  NonHispanic
# 25   2019-08-17T11:53:00.0 2019 8     Male   Black                  Hispanic
# 26   2019-08-17T00:00:00.0 2019 8     Male   White                  Hispanic
# 27   2019-08-16T16:56:00.0 2019 8     Male   White                  Hispanic
# 28   2019-08-16T00:43:00.0 2019 8     Male   Black                  Hispanic
# 29   2019-08-16T00:00:00.0 2019 8     Male   Black                  NonHispanic
# 30   2019-08-16T00:00:00.0 2019 8     Male   Black                  NonHispanic
# ⋮    ⋮                     ⋮    ⋮     ⋮      ⋮                      ⋮
# 2863 2021-09-18T19:25:00.0 2021  9    Male   White                  NonHispanic
# 2864 2021-09-18T19:25:00.0 2021  9    Male   White                  NonHispanic
# 2865 2021-09-18T19:25:00.0 2021  9    Male   White                  NonHispanic
# 2866 2021-09-20T17:53:00.0 2021  9    Male   Black                  Hispanic
# 2867 2021-09-20T21:30:00.0 2021  9    Male   White                  Hispanic
# 2868 2021-09-09T00:00:00.0 2021  9    Male   White                  Unknown
# 2869 2021-09-21T11:30:00.0 2021  9    Male   Black                  NonHispanic
# 2870 2021-09-21T11:30:00.0 2021  9    Male   Black                  NonHispanic
# 2871 2021-09-21T11:30:00.0 2021  9    Male   Black                  NonHispanic
# 2872 2021-09-21T11:30:00.0 2021  9    Male   Black                  NonHispanic
# 2873 2021-09-21T18:04:00.0 2021  9    Male   Black                  Hispanic
# 2874 2021-09-22T14:40:00.0 2021  9    Male   White                  Hispanic
# 2875 2021-09-22T16:17:00.0 2021  9    Male   Black                  NonHispanic
# 2876 2021-09-23T00:00:00.0 2021  9    Male   Asian/Pacific Islander NULL
# 2877 2021-09-24T05:20:00.0 2021  9    Male   Black                  Hispanic
# 2878 2021-09-24T20:00:00.0 2021  9    Male   White                  Hispanic
# 2879 2021-09-25T12:20:00.0 2021  9    Male   White                  NonHispanic
# 2880 2021-09-25T12:20:00.0 2021  9    Male   White                  NonHispanic
# 2881 2021-09-26T04:54:00.0 2021  9    Male   Black                  NonHispanic
# 2882 2021-09-26T19:20:00.0 2021  9    Male   White                  Hispanic
# 2883 2021-09-20T21:30:00.0 2021  9    Male   White                  Hispanic
# 2884 2021-09-24T05:20:00.0 2021  9    Male   Black                  Hispanic
# 2885 2021-09-27T16:08:00.0 2021  9    Male   White                  Hispanic
# 2886 2021-09-29T06:06:00.0 2021  9    Male   Black                  Hispanic
# 2887 2021-09-28T22:33:00.0 2021  9    Male   Black                  NonHispanic
# 2888 2021-09-28T11:00:00.0 2021  9    Male   Black                  NonHispanic
# 2889 2021-09-29T07:05:00.0 2021  9    Male   White                  Hispanic
# 2890 2021-09-29T21:12:00.0 2021  9    Male   Black                  NonHispanic
# 2891 2021-09-29T00:00:00.0 2021  9    Male   Black                  NonHispanic
# 2892 2021-10-01T00:05:00.0 2021 10    Male   Black                  Hispanic
#      year_of_birth age from_address         from_city        from_state
# 1    1996          22  DOUGLAS              Providence
# 2    2000          19  MOWRY ST             Providence
# 3    2000          19  MOWRY ST             Providence
# 4    1996          23  CUMERFORD ST         Providence
# 5    1996          23  CUMERFORD ST         Providence
# 6    1998          20  LAURA ST             Providence
# 7    1998          21  AUSTIN ST            newbrdford
# 8    1999          20  ROCKINGHAM ST        Providence       Rhode Island
# 9    1998          21  HOLLIS ST            Providence
# 10   1998          21  CUMERFORD ST         Providence
# 11   1995          23  MINTO ST             Providence
# 12   1999          19  MELISSA AVE          Providence
# 13   1999          19  MELISSA AVE          Providence
# 14   1999          19  MELISSA AVE          Providence
# 15   1999          20  VIOLET ST            Providence
# 16   1999          19  MINK RD              Providence       Rhode Island
# 17   2000          19  SMITH ST             Providence
# 18   1997          21  PARNELL ST           Providence
# 19   1998          20  WASHINGTON ST        Providence
# 20   1996          23  LEE RD               e. providence
# 21   1996          23  LEE RD               e. providence
# 22   1999          20  WENDELL ST           Providence
# 23   1998          21  HOWE STREET          MANCHESTER
# 24   1964          55  SOUTH UNION ST       Pawtucket
# 25   1999          20  HOMESTEAD AVE        Providence
# 26   2001          18  BENEDICT ST          Providence
# 27   1995          23  WINTHROP AVE         Providence
# 28   1998          20  LINTON ST            Pawtucket
# 29   1996          22  No Permanent Address Providence
# 30   1996          22  No Permanent Address Providence
# ⋮    ⋮             ⋮   ⋮                    ⋮                ⋮
# 2863 2001          20  CUNNINGHAM SQ        Providence       NULL
# 2864 2001          20  WYNDEMARK CT.        Cheshire         NULL
# 2865 2002          18  CUNNINGHAM SQ        Providence       NULL
# 2866 2001          20  POST RD              Warwick          NULL
# 2867 1998          22  ALEXANDER ST         Providence       NULL
# 2868 1998          23  BROAD ST             Providence       NULL
# 2869 2003          18  PARKIS AVE           Providence       NULL
# 2870 2003          18  PARKIS AVE           Providence       NULL
# 2871 2003          18  PARKIS AVE           Providence       NULL
# 2872 2003          18  PARKIS AVE           Providence       NULL
# 2873 1999          22  PETER ST             Providence       NULL
# 2874 1952          68  OSBORN ST            Providence       Rhode Island
# 2875 2001          19  BLANCHAARD AVE       WARWICK          NULL
# 2876 1944          77  DOUGLAS AVENUE 4101  North Providence NULL
# 2877 1998          23  NULL                 NULL             NULL
# 2878 1998          23  MADISON ST           Providence       NULL
# 2879 2001          20  GODDARD ST           Providence       NULL
# 2880 2001          20  GODDARD ST           Providence       NULL
# 2881 1998          23  MCTEER CT            WEST WARWICK     NULL
# 2882 1999          22  No Permanent Address NULL             NULL
# 2883 1998          22  ALEXANDER ST         Providence       NULL
# 2884 1998          23  NULL                 NULL             NULL
# 2885 1998          23  METCALF ST           Providence       Rhode Island
# 2886 2000          20  FORD ST              Providence       NULL
# 2887 2002          19  CHALKSTONE AVE       Providence       NULL
# 2888 1954          66  PUBLIC ST            Providence       NULL
# 2889 2001          20  JULIAN ST            Providence       NULL
# 2890 1973          48  ARMISTICE BOULEVARD  Pawtucket        NULL
# 2891 1954          67  RUSSO ST             Providence       NULL
# 2892 1952          68  PHEBE ST             Providence       Rhode Island
#      statute_type             statute_code
# 1    RI Statute Violation     11-44-1
# 2    RI Statute Violation     31-27-4
# 3    RI Statute Violation     31-11-18
# 4    RI Statute Violation     12-7-10
# 5    RI Statute Violation     11-32-1
# 6    RI Statute Violation     11-44-1
# 7    RI Statute Violation     11-5-3
# 8    RI Statute Violation     31-11-18
# 9    RI Statute Violation     11-47-5.2
# 10   RI Statute Violation     31-11-18
# 11   RI Statute Violation     31-26-2
# 12   RI Statute Violation     12-7-10
# 13   RI Statute Violation     11-45-1
# 14   RI Statute Violation     31-11-18
# 15
# 16   RI Statute Violation     31-27-4
# 17
# 18   RI Statute Violation     11-5-3
# 19
# 20   Warrant\\Capias          BWARRANT-6D
# 21   RI Statute Violation     31-11-18
# 22
# 23   RI Statute Violation     11-45-1
# 24
# 25   RI Statute Violation     31-11-18
# 26   RI Statute Violation     11-37-2
# 27   RI Statute Violation     21-28-4.01-A2A
# 28   RI Statute Violation     21-28-4.01-C1A
# 29   RI Statute Violation     11-41-24
# 30   RI Statute Violation     11-41-20
# ⋮    ⋮                        ⋮
# 2863 RI Statute Violation     3-8-10
# 2864 RI Statute Violation     3-8-10
# 2865 RI Statute Violation     3-8-10
# 2866 NULL                     NULL
# 2867 NULL                     NULL
# 2868 NULL                     NULL
# 2869 RI Statute Violation     11-5-2
# 2870 RI Statute Violation     11-47-8-A
# 2871 RI Statute Violation     11-47-3.2-B
# 2872 RI Statute Violation     11-1-6
# 2873 RI Statute Violation     11-5-3
# 2874 NULL                     NULL
# 2875 NULL                     NULL
# 2876 NULL                     NULL
# 2877 NULL                     NULL
# 2878 RI Statute Violation     11-45-1
# 2879 RI Statute Violation     11-5-3
# 2880 Municipal Code Violation Sec. 16-3.C
# 2881 RI Statute Violation     11-47-8-A
# 2882 RI Statute Violation     11-41-20
# 2883 RI Statute Violation     12-29-4
# 2884 RI Statute Violation     11-5-3
# 2885 NULL                     NULL
# 2886 NULL                     NULL
# 2887 RI Statute Violation     31-11-18
# 2888 RI Statute Violation     11-37.1-3
# 2889 RI Statute Violation     11-8-2
# 2890 RI Statute Violation     11-44-1
# 2891 RI Statute Violation     11-5-3
# 2892 NULL                     NULL
#      statute_desc                                                       counts
# 1    DOMESTIC-VANDALISM/MALICIOUS INJURY TO PROP                         1
# 2    Reckless Driving, Drag Racing - Attempting to Elude                 1
# 3    Driving after Denial, Suspension or Revocation of License           1
# 4    RESISTING LEGAL OR ILLEGAL ARREST                                   1
# 5    OBSTRUCTING OFFICER IN EXECUTION OF DUTY                            1
# 6    DOMESTIC-VANDALISM/MALICIOUS INJURY TO PROP                         1
# 7    SIMPLE ASSAULT OR BATTERY                                           1
# 8    Driving after Denial, Suspension or Revocation of License           1
# 9    POSSESSION OF A STOLEN FIREARM                                      1
# 10   Driving after Denial, Suspension or Revocation of License           1
# 11   Duty to Stop in Accidents Resulting in Damage to Attended Vehicles  1
# 12   RESISTING LEGAL OR ILLEGAL ARREST                                   1
# 13   DISORDERLY CONDUCT                                                  1
# 14   Driving after Denial, Suspension or Revocation of License           1
# 15                                                                      NA
# 16   Reckless Driving, Drag Racing - Attempting to Elude                 1
# 17                                                                      NA
# 18   SIMPLE ASSAULT OR BATTERY                                           1
# 19                                                                      NA
# 20   BENCH WARRANT ISSUED FROM 6TH DISTRICT COURT                        1
# 21   Driving after Denial, Suspension or Revocation of License           1
# 22                                                                      NA
# 23   DISORDERLY CONDUCT                                                  1
# 24                                                                      NA
# 25   Driving after Denial, Suspension or Revocation of License           1
# 26   SEXUAL ASSAULT -1ST DEGREE - FRC RAPE                               1
# 27   MANUFAC/POSS/DELIVER SCH 1/II                                       1
# 28   POSSESSION OF SCHEDULE I II III                                     1
# 29   HABITUAL OFFENDER-SHOPLIFTING                                       1
# 30   SHOPLIFTING-FELONY - SHOPLIFTING                                    1
# ⋮    ⋮                                                                  ⋮
# 2863 POSSESSION OF BEVERAGE-UNDERAGE PERSONS                             1
# 2864 POSSESSION OF BEVERAGE-UNDERAGE PERSONS                             1
# 2865 POSSESSION OF BEVERAGE-UNDERAGE PERSONS                             1
# 2866 NULL                                                               NA
# 2867 NULL                                                               NA
# 2868 NULL                                                               NA
# 2869 FELONY ASSAULT/ DANG. WEAPON OR SUBSTANCE                           1
# 2870 LICENSE OR PERMIT REQUIRED FOR CARRYING PISTOL                      1
# 2871 DISCHARGE OF FA WHILE COMMITTING CRIME OF VIOLENCE                  1
# 2872 CONSPIRACY - ALL OTH OFFENSE                                        1
# 2873 DOMESTIC-SIMPLE ASSAULT/BATTERY                                     1
# 2874 NULL                                                               NA
# 2875 NULL                                                               NA
# 2876 NULL                                                               NA
# 2877 NULL                                                               NA
# 2878 DISORDERLY CONDUCT                                                  1
# 2879 DOMESTIC-SIMPLE ASSAULT/BATTERY                                     1
# 2880 Disorderly Conduct C - Fighting Words                               1
# 2881 LICENSE OR PERMIT REQUIRED FOR CARRYING PISTOL                      1
# 2882 SHOPLIFTING-MISD - SHOPLIFTING                                      1
# 2883 VIOLATION -NO CONTACT ORDER                                         1
# 2884 DOMESTIC-SIMPLE ASSAULT/BATTERY                                     1
# 2885 NULL                                                               NA
# 2886 NULL                                                               NA
# 2887 Driving after Denial, Suspension or Revocation of License           1
# 2888 SEXUAL OFFENDER REGISTRATION REQUIRED                               1
# 2889 B&E DWELLING HOUSE W/O CONSENT                                      1
# 2890 VANDALISM/MALICIOUS INJURY TO PROPERTY                              1
# 2891 SIMPLE ASSAULT OR BATTERY                                           1
# 2892 NULL                                                               NA
#      case_number
# 1    2019-00084031
# 2    2019-00083996
# 3    2019-00083996
# 4    2019-00083963
# 5    2019-00083963
# 6    2019-00083892
# 7    2019-00083725
# 8    2019-00083486
# 9    2019-00083396
# 10   2019-00083274
# 11   2019-00083178
# 12   2019-00083170
# 13   2019-00083170
# 14   2019-00083170
# 15   2019-00082937
# 16   2019-00078616
# 17   2019-00082826
# 18   2019-00082422
# 19   2019-00082384
# 20   2019-00082356
# 21   2019-00082356
# 22   2019-00081915
# 23   2019-00081919
# 24   2019-00081782
# 25   2019-00081587
# 26   2019-00081517
# 27   2019-00081240
# 28   2019-00081015
# 29   2019-00081319
# 30   2019-00081319
# ⋮    ⋮
# 2863 2021-00074005
# 2864 2021-00074005
# 2865 2021-00074005
# 2866 2021-00074597
# 2867 2021-00074648
# 2868 2021-00071029
# 2869 2021-00062608
# 2870 2021-00062608
# 2871 2021-00062608
# 2872 2021-00062608
# 2873 2021-00074894
# 2874 2021-00075094
# 2875 2021-00075126
# 2876 2021-00075345
# 2877 2021-00075561
# 2878 2021-00075783
# 2879 2021-00075997
# 2880 2021-00075997
# 2881 2021-00076278
# 2882 2021-00076436
# 2883 2021-00074648
# 2884 2021-00075561
# 2885 2021-00076724
# 2886 2021-00077156
# 2887 2021-00077115
# 2888 2020-00004402
# 2889 2021-00077161
# 2890 2021-00077382
# 2891 2021-00077379
# 2892 2021-00077654
#      arresting_officers
# 1     RCarlin, SKennedy
# 2     SCampbell, RMalloy
# 3     SCampbell, RMalloy
# 4     JHanley
# 5     JHanley
# 6     JCotugno, ALevesque, JButen, JJohnson
# 7     PSalmons
# 8     JBenros, MClary
# 9     RFedo, KRosado, ALugo
# 10    JMadeira
# 11    JLugo
# 12    ITavarez, IYousif, CBrown, EDelgado
# 13    ITavarez, IYousif, CBrown, EDelgado
# 14    ITavarez, IYousif, CBrown, EDelgado
# 15    EBreault, LMarroquin, KRichards, TSavard, DDiaz
# 16    JGagnon, RMalloy
# 17    RPapa, MCamardo
# 18    JRodrigues, DForte
# 19    JStanzione, DHernandez
# 20    LFernandez, CBenoit, CClift
# 21    LFernandez, CBenoit, CClift
# 22    KRosado, FTavares
# 23    SKennedy
# 24    DHernandez
# 25    JBenros, JCotugno
# 26    RMendez, JNajarian
# 27    NOC Officer
# 28    BMcKenna
# 29    RAbenante, RGaudiana
# 30    RAbenante, RGaudiana
# ⋮    ⋮
# 2863 Shields, Derek/ Castro, Ludwig
# 2864 Shields, Derek/ Castro, Ludwig
# 2865 Shields, Derek/ Castro, Ludwig
# 2866 Rousseau, Matthew
# 2867 Moore, Anthony
# 2868 Diaz, Alex
# 2869 Stanzione, Jared
# 2870 Stanzione, Jared
# 2871 Stanzione, Jared
# 2872 Stanzione, Jared
# 2873 Mancini, Mark/ Breault, Erik/ Calandra, Tyler/ Savard, Thomas
# 2874 Savard, Thomas
# 2875 Pirolli, Jonathyn
# 2876 Lopes, Joseph
# 2877 Santos, Alexandre/ Subramaniam, Ajay
# 2878 Potter, Patrick
# 2879 Rodrigues, Juan/ Tavarez, Ivan
# 2880 Rodrigues, Juan/ Tavarez, Ivan
# 2881 Calle, Andrew/ Prete, Louis/ Subramaniam, Ajay/ Ventura, Hansel
# 2882 Im, Southavout/ Anderson, Darrin
# 2883 Moore, Anthony
# 2884 Santos, Alexandre/ Subramaniam, Ajay
# 2885 Hines, Christopher
# 2886 Addai, Mabel/ Prete, Louis/ Subramaniam, Ajay
# 2887 Vingi, Cory
# 2888 Stanzione, Jared
# 2889 Dalton, Jason/ Valletta, Giana
# 2890 Doldoorian, Kirsten/ Lugo, Abraham
# 2891 Criner, Raymond
# 2892 Silva, Eric
#      id
# 1    pvd15614289459563584867
# 2    pvd900460037611487829
# 3    pvd900460037611487829
# 4    pvd1675234703933765967
# 5    pvd1675234703933765967
# 6    pvd17953747948212880432
# 7    pvd3024232238010666153
# 8    pvd8008374038901187780
# 9    pvd6386847572324309475
# 10   pvd14028206778351997883
# 11   pvd15484437773558878491
# 12   pvd5047836359365815220
# 13   pvd5047836359365815220
# 14   pvd5047836359365815220
# 15   pvd11307430541739268546
# 16   pvd1076862233562848683
# 17   pvd12708633210022966227
# 18   pvd1659949234730464312
# 19   pvd14980793063563348172
# 20   pvd8740720143141443756
# 21   pvd8740720143141443756
# 22   pvd11381887219559117536
# 23   pvd11675033727467519694
# 24   pvd17574977003499591740
# 25   pvd16591707559944991069
# 26   pvd9938776757456909177
# 27   pvd17516830937488095084
# 28   pvd9281906170407203949
# 29   pvd10959757297184382072
# 30   pvd10959757297184382072
# ⋮    ⋮
# 2863 pvd6205748667965642541
# 2864 pvd16397125318715867803
# 2865 pvd5195074301745935018
# 2866 pvd16301983516170635166
# 2867 pvd3638004533788767077
# 2868 pvd16722556137071805905
# 2869 pvd13474061105520308850
# 2870 pvd13474061105520308850
# 2871 pvd13474061105520308850
# 2872 pvd13474061105520308850
# 2873 pvd4576819876417022713
# 2874 pvd15228838999240996878
# 2875 pvd3396272140312660794
# 2876 pvd15274332284830779319
# 2877 pvd7703140614960407244
# 2878 pvd14393267306680258758
# 2879 pvd15281745511360817394
# 2880 pvd15281745511360817394
# 2881 pvd7899318447387645526
# 2882 pvd10454924037835051453
# 2883 pvd3638004533788767077
# 2884 pvd7703140614960407244
# 2885 pvd14295253119011323372
# 2886 pvd5794071766434905521
# 2887 pvd6105586092259284839
# 2888 pvd12048292079609555360
# 2889 pvd4887358463020255390
# 2890 pvd1573280805693708985
# 2891 pvd11372458517369102932
# 2892 pvd10501230489459422006

# %% [markdown]
# <center><h1>Using <code>select()</code> Function in dplyr</h1></center>

# %% [markdown]
# # 8. Using `select()` to Extract Columns
#   - Recall that `filter()` can be used to filter rows
#   - Similarly, `select()` is used to select columns
#   - These functions can be "chained"

# %% [markdown]
# ## 8.1 Example of `select()`

# %%
arrests_subset <- arrests_df %>% 
    select(id, age, gender, statute_desc)

head(arrests_subset)
# Out:
#   id                      age gender
# 1 pvd2218242150382148273  37  Male
# 2 pvd15166785558364246202 25
# 3 pvd3142917706201385905  34  Female
# 4 pvd3142917706201385905  34  Female
# 5 pvd460449304532374599   18  Female
# 6 pvd460449304532374599   18  Female
#   statute_desc
# 1
# 2 Driving after Denial, Suspension or Revocation of License
# 3 RESISTING LEGAL OR ILLEGAL ARREST
# 4 DISORDERLY CONDUCT
# 5 RESISTING LEGAL OR ILLEGAL ARREST
# 6 DISORDERLY CONDUCT

# %% [markdown]
# ### 8.1.1 Comparing `select()` to `[, ]` notation

# %%
# dplyr example
arrests_df %>% 
    select(id, age, gender, statute_desc)


# equivalent in "base" R example
cols <- c("id", "age", "gender", "statute_desc")

arrest_sub <- arrests_df[, cols]

head(arrest_sub)
# Out:
#       id                      age gender
# 1     pvd2218242150382148273  37  Male
# 2     pvd15166785558364246202 25
# 3     pvd3142917706201385905  34  Female
# 4     pvd3142917706201385905  34  Female
# 5     pvd460449304532374599   18  Female
# 6     pvd460449304532374599   18  Female
# 7     pvd460449304532374599   18  Female
# 8     pvd6431558757894418021  28  Male
# 9     pvd6431558757894418021  28  Male
# 10    pvd6431558757894418021  28  Male
# 11    pvd15614289459563584867 22  Male
# 12    pvd900460037611487829   19  Male
# 13    pvd900460037611487829   19  Male
# 14    pvd1675234703933765967  23  Male
# 15    pvd1675234703933765967  23  Male
# 16    pvd8555094992612905738  45  Female
# 17    pvd8555094992612905738  45  Female
# 18    pvd17953747948212880432 20  Male
# 19    pvd15100522507516509426 47  Male
# 20    pvd1784400650677464818  30  Male
# 21    pvd1784400650677464818  30  Male
# 22    pvd17906628124789383577 54  Male
# 23    pvd2709931773722136485  39  Male
# 24    pvd3024232238010666153  21  Male
# 25    pvd5436004350740110700  40  Male
# 26    pvd5436004350740110700  40  Male
# 27    pvd18360527540285642844 59  Male
# 28    pvd18360527540285642844 59  Male
# 29    pvd6329853531447301575  38  Male
# 30    pvd4717540273846557288  31  Female
# ⋮     ⋮                       ⋮   ⋮
# 12983 pvd6105586092259284839  19  Male
# 12984 pvd97181106785067831    31  Female
# 12985 pvd6705144404890367751  34  Male
# 12986 pvd6705144404890367751  34  Male
# 12987 pvd3277432090627726485  41  Male
# 12988 pvd12048292079609555360 66  Male
# 12989 pvd657108210480191387   35  Male
# 12990 pvd16555751539640578946 50  Male
# 12991 pvd4887358463020255390  20  Male
# 12992 pvd7910670241515922769  41  Female
# 12993 pvd12511021050990858630 37  Male
# 12994 pvd1573280805693708985  48  Male
# 12995 pvd12563331084039738945 60  Female
# 12996 pvd11372458517369102932 67  Male
# 12997 pvd7675372766478296352  55  Male
# 12998 pvd7675372766478296352  55  Male
# 12999 pvd7675372766478296352  55  Male
# 13000 pvd6782462755387617562  32  Female
# 13001 pvd8344990625170182930  33  Male
# 13002 pvd11832376381973364540 42  Male
# 13003 pvd14935609672162974356 31  Male
# 13004 pvd8433436421423571594  34  Male
# 13005 pvd10005979167793807438 57  Female
# 13006 pvd1854345170741977353  35  Male
# 13007 pvd10290435390801352104 42  Female
# 13008 pvd10290435390801352104 42  Female
# 13009 pvd10290435390801352104 42  Female
# 13010 pvd10290435390801352104 42  Female
# 13011 pvd10501230489459422006 68  Male
# 13012 pvd6857941429842573728  40  Male
#       statute_desc
# 1
# 2     Driving after Denial, Suspension or Revocation of License
# 3     RESISTING LEGAL OR ILLEGAL ARREST
# 4     DISORDERLY CONDUCT
# 5     RESISTING LEGAL OR ILLEGAL ARREST
# 6     DISORDERLY CONDUCT
# 7     OBSTRUCTING OFFICER IN EXECUTION OF DUTY
# 8     Chemical Test Refusal
# 9     Driving Under the Influence of Liqour or Drugs (=>.08<.1)
# 10    Driving after Denial, Suspension or Revocation of License
# 11    DOMESTIC-VANDALISM/MALICIOUS INJURY TO PROP
# 12    Reckless Driving, Drag Racing - Attempting to Elude
# 13    Driving after Denial, Suspension or Revocation of License
# 14    RESISTING LEGAL OR ILLEGAL ARREST
# 15    OBSTRUCTING OFFICER IN EXECUTION OF DUTY
# 16    VANDALISM/MALICIOUS INJURY TO PROPERTY
# 17    Disorderly and Indecent Conduct B - Loud Noise
# 18    DOMESTIC-VANDALISM/MALICIOUS INJURY TO PROP
# 19    Driving after Denial, Suspension or Revocation of License
# 20    MANUFACTURE/POSS/DELIVER SCH III/IV
# 21    MANUFAC/POSS/DELIVER SCH 1/II
# 22    Driving after Denial, Suspension or Revocation of License
# 23
# 24    SIMPLE ASSAULT OR BATTERY
# 25    CONTROLLED SUBSTANCE CONSPIRACY
# 26    MANUFAC/POSS/DELIVER SCH 1/II
# 27    CONTROLLED SUBSTANCE CONSPIRACY
# 28    MANUFAC/POSS/DELIVER SCH 1/II
# 29
# 30    BENCH WARRANT ISSUED FROM SUPERIOR COURT
# ⋮     ⋮
# 12983 Driving after Denial, Suspension or Revocation of License
# 12984 DISORDERLY CONDUCT
# 12985 VIOLATION -NO CONTACT ORDER
# 12986 DOMESTIC-ROBBERY-2ND DEGREE
# 12987 DOMESTIC-SIMPLE ASSAULT/BATTERY
# 12988 SEXUAL OFFENDER REGISTRATION REQUIRED
# 12989 Driving after Denial, Suspension or Revocation of License
# 12990 Duty to Stop in Accidents Resulting in Damage to Attended Vehicles
# 12991 B&E DWELLING HOUSE W/O CONSENT
# 12992 SIMPLE ASSAULT OR BATTERY
# 12993 VIOLATION OF PROTECTIVE ORDER
# 12994 VANDALISM/MALICIOUS INJURY TO PROPERTY
# 12995 DOMESTIC-SIMPLE ASSAULT/BATTERY
# 12996 SIMPLE ASSAULT OR BATTERY
# 12997 Chemical Test Refusal
# 12998 Driving Under the Influence of Liqour or Drugs (=>.08<.1)
# 12999 Driving after Denial, Suspension or Revocation of License
# 13000 Driving Under the Influence of Liqour or Drugs (=>.08<.1)
# 13001 CRUELTY TO OR NEGLECT OF CHILD
# 13002 B&E BUS.PLACE PUBLIC BLDG  OR SHIP W/FEL. INTENT
# 13003 FELONY ASSAULT/ DANG. WEAPON OR SUBSTANCE
# 13004 WARRANT OF ARREST ON AFFIDAVIT - ALL OTH OFFENSE
# 13005 VANDALISM/MALICIOUS INJURY TO PROPERTY
# 13006 SIMPLE ASSAULT OR BATTERY
# 13007 POSSESSION OF SCHEDULE I II III
# 13008 SIMPLE ASSAULT OR BATTERY
# 13009 DISORDERLY CONDUCT
# 13010 OBSTRUCTING OFFICER IN EXECUTION OF DUTY
# 13011 NULL
# 13012 NULL
#   id                      age gender
# 1 pvd2218242150382148273  37  Male
# 2 pvd15166785558364246202 25
# 3 pvd3142917706201385905  34  Female
# 4 pvd3142917706201385905  34  Female
# 5 pvd460449304532374599   18  Female
# 6 pvd460449304532374599   18  Female
#   statute_desc
# 1
# 2 Driving after Denial, Suspension or Revocation of License
# 3 RESISTING LEGAL OR ILLEGAL ARREST
# 4 DISORDERLY CONDUCT
# 5 RESISTING LEGAL OR ILLEGAL ARREST
# 6 DISORDERLY CONDUCT

# %% [markdown]
# ## 8.2 Example of `select()` (cont.)

# %%
arrests_vio <- arrests_df %>%
    select(
        id,
        age,
        gender,
        statute_desc
    )

# %%
head(arrests_vio)           # see first few lines of new dataframe
# Out:
#   id                      age gender
# 1 pvd2218242150382148273  37  Male
# 2 pvd15166785558364246202 25
# 3 pvd3142917706201385905  34  Female
# 4 pvd3142917706201385905  34  Female
# 5 pvd460449304532374599   18  Female
# 6 pvd460449304532374599   18  Female
#   statute_desc
# 1
# 2 Driving after Denial, Suspension or Revocation of License
# 3 RESISTING LEGAL OR ILLEGAL ARREST
# 4 DISORDERLY CONDUCT
# 5 RESISTING LEGAL OR ILLEGAL ARREST
# 6 DISORDERLY CONDUCT

# %% [markdown]
# # 9. Chaining _dplyr_ Operators
#   - One key reason for _dplyr_ popularity
#   - _dplyr_ verbs/functions are "composable"
#     + $(f \circ g)(x) == f(g(x))$

# %%
female_vio <- arrests_df %>%
    filter(gender == "Female") %>%
    select(id, age, gender, statute_desc)

head(female_vio)
# Out:
#   id                     age gender statute_desc
# 1 pvd3142917706201385905 34  Female RESISTING LEGAL OR ILLEGAL ARREST
# 2 pvd3142917706201385905 34  Female DISORDERLY CONDUCT
# 3 pvd460449304532374599  18  Female RESISTING LEGAL OR ILLEGAL ARREST
# 4 pvd460449304532374599  18  Female DISORDERLY CONDUCT
# 5 pvd460449304532374599  18  Female OBSTRUCTING OFFICER IN EXECUTION OF DUTY
# 6 pvd8555094992612905738 45  Female VANDALISM/MALICIOUS INJURY TO PROPERTY

# %% [markdown]
# ## 9.1 More Chaining

# %%
female_midage <- arrests_df %>%
    filter(
        gender == "Female",
        age > 45,
        statute_desc != ""
    ) %>%
    select(
        id, 
        age, 
        gender,
        statute_desc
    ) %>%
    arrange(
        age
    )

head(female_midage)
# Out:
#   id                      age gender
# 1 pvd5910286289754155205  46  Female
# 2 pvd14925567736676696725 46  Female
# 3 pvd17492545928832438170 46  Female
# 4 pvd6439318455139528590  46  Female
# 5 pvd5910286289754155205  46  Female
# 6 pvd13975960782588463013 46  Female
#   statute_desc
# 1 LOITERING FOR INDECENT PURPOSES PROSTITUTION - PROSTITUTION
# 2 SHOPLIFTING-MISD - SHOPLIFTING
# 3 Driving after Denial, Suspension or Revocation of License
# 4 BENCH WARRANT ISSUED FROM 6TH DISTRICT COURT
# 5 LOITERING FOR INDECENT PURPOSES PROSTITUTION - PROSTITUTION
# 6 SIMPLE ASSAULT OR BATTERY

# %% [markdown]
# <center><h1>Challenge Problem</h1></center>
#
# In addition to the arrests data, the Providence Police Department also makes data concerning criminal cases available. This is in the CSV file called `"pvd_cases_2021-10-03.csv"` in the `data/` directory of this repository.
#
#   1. Let's read the cases data in from a CSV and call it `cases_df`.
#   2. Then, let's create a new dataframe that is a subset of `cases_df`. In particular, let's create a dataframe called `cases_summer_df` that contains only those cases that were heard in June, July, or August.
#
#
# **Note**: The `month` columns is coded numerically in the data set, so keep that in mind.

# %%
cases_df <- read.csv("data/pvd_cases_2021-10-03.csv") 

cases_summer_df <- case_df %>%
    filter(
        month >= 6,
        month < 9
    ) %>%
    group_by(month) %>%
    summarize(
        n_rows = n()
    )

cases_summer_df
# Out:
# Error in filter(., month >= 6, month < 9): object 'case_df' not found
# Traceback:
#
# 1. case_df %>% filter(month >= 6, month < 9) %>% group_by(month) %>%
#  .     summarize(n_rows = n())
# 2. summarize(., n_rows = n())
# 3. group_by(., month)
# 4. filter(., month >= 6, month < 9)

# %%
cases_summer_df_2 <- case_df %>%
    filter(
        month == 6 | month == 7 | month == 8
    ) %>%
    group_by(month) %>%
    summarize(
        n_rows = n()
    )

cases_summer_df_2

# %% [markdown]
# <center><h1>Using <code>group_by()</code> and <code>summarise()</code> in dplyr</h1></center>

# %% [markdown]
# # 10. Why use `group_by()` and `summarise()` from _dplyr_?
#   - Being able to aggregate and summarize by grouping is hugely common
#   - _split-apply-combine_ pattern
#   - These operations can be "chained" with other _dplyr_ functions
#   - Often makes for concise, intuitive, and readable code

# %% [markdown]
# ## 10.1 Example of `group_by()` and `summarise()`

# %%
gender_tbl <- arrests_df %>%
    group_by(gender) %>%
    summarise(
        n_rows = n(),
        mean_age = mean(age)
    ) 

gender_tbl
# Out:
#   gender  n_rows mean_age
# 1            21  29.47619
# 2 Female   2777  32.10839
# 3 Male    10170  33.35890
# 4 NULL       36  26.61111
# 5 Unknown     8  35.12500

# %% [markdown]
# # 11. Chaining `filter()` with `group_by()` and `summarise()`

# %%
gender_tbl <- arrests_df %>%
    filter(
        from_city == "Providence",
        year == 2019
    ) %>%
    group_by(gender) %>%
    summarise(
        n_rows = n(),
        mean_age = mean(age),
        mean_cnts = mean(counts, na.rm = TRUE)
    )

head(gender_tbl)
# Out:
#   gender  n_rows mean_age mean_cnts
# 1            9   23.88889 1.000000
# 2 Female   515   33.46602 1.064039
# 3 Male    2039   33.38941 1.098027
# 4 Unknown    1   49.00000 1.000000

# %% [markdown]
# ## 11.1 More Interesting Example of Chaining

# %%
is_summer <- function(month_num) {
    
    chk <- month_num %in% c(6, 7, 8)
    return(chk)
}

# %%
is_summer(6)   # TRUE
is_summer(2)   # FALSE
is_summer(8)   # TRUE
# Out:
# [1] TRUE
# [1] FALSE
# [1] TRUE

# %% [markdown]
# ### 11.1.1 More Interesting Example (cont.)

# %%
vio_tbl <- arrests_df %>%
    filter(
        statute_desc != "",
        statute_desc != "NULL", 
        year == 2021
    ) %>%
    group_by(statute_desc) %>%
    summarise(
        n_vios = n(),
        prop_male = mean(gender == "Male"),
        mean_age = mean(age),
        prop_summer = mean(is_summer(month))
    ) %>%
    arrange(desc(n_vios))

head(vio_tbl)
# Out:
#   statute_desc                                              n_vios prop_male
# 1 DOMESTIC-SIMPLE ASSAULT/BATTERY                           290    0.7482759
# 2 Driving after Denial, Suspension or Revocation of License 237    0.7552743
# 3 DISORDERLY CONDUCT                                        132    0.8106061
# 4 SIMPLE ASSAULT OR BATTERY                                 115    0.7304348
# 5 BENCH WARRANT ISSUED FROM SUPERIOR COURT                  106    0.8301887
# 6 LICENSE OR PERMIT REQUIRED FOR CARRYING PISTOL             94    0.9787234
#   mean_age prop_summer
# 1 33.13448 0.3068966
# 2 31.91561 0.3459916
# 3 30.73485 0.3409091
# 4 35.33913 0.3043478
# 5 37.04717 0.2735849
# 6 26.47872 0.2978723

# %% [markdown]
# <center><h1>Challenge Problem</h1></center>
#
# Suppose we are interested in the distribution of states of origin (i.e., `from_state`) for the males arrested in the summer months (i.e., June, July, August). Let's use dplyr to create a table with the counts of individuals from the different cities in our arrests data.
#
# To accomplish this, we will use the `filter()`, `group_by()`, and `summarise()` functions. The table should end up having two columns `from_state`, and `num_arrests`.

# %%
male_summer_tbl <- arrests_df %>%
    filter(
        gender == "Male",
        is_summer(month)
    ) %>% 
    group_by(from_state) %>%
    summarize(
        num_arrests = n()
    ) %>%
    arrange(desc(num_arrests))

male_summer_tbl
# Out:
#    from_state    num_arrests
# 1  NULL          1342
# 2                 682
# 3  Rhode Island   641
# 4  Massachusetts   20
# 5  Connecticut      6
# 6  Georgia          6
# 7  New York         5
# 8  New Mexico       4
# 9  Missouri         2
# 10 North Dakota     2
# 11 Illinois         1
# 12 New Jersey       1
# 13 Pennsylvania     1
